# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\DATA SCIENCE AND ML\Project\job_trend_predictor\fresher_jobs_sample.csv")

# %%
df
# Out:
#                                                 Title  \
# 0                                    Python Developer
# 1   Python Developer / Java Developer / .net Devel...
# 2                       Python Developer Trainee - 05
# 3                        Associate Software Developer
# 4                                    Python Developer
# 5                              Data and Legal Analyst
# 6                 Winfrox Hiring Remote Data Analysts
# 7                                    Power BI Trainee
# 8                                        Data Analyst
# 9                            Custom Software Engineer
# 10                                  Software Engineer
# 11                           Custom Software Engineer
# 12  Data Analyst / Freshers / Software Engineer / ...
# 13                       Software Engineer - Freshers
# 14                               AI Software Engineer
# 15                          Trainee Software Engineer
# ...
