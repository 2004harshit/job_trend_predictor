# %%
import pandas as pd
import numpy as np

# %%
df.columns
# Out:
# Index(['Title', 'Company', 'Experience', 'Salary', 'Location', 'Education',
#        'Star_Skills', 'Normal_Skills', 'Posted_Date', 'Last_Apply_Date',
#        'Role', 'Industry Type', 'Department', 'Employment Type',
#        'Role Category', 'Description', 'Job_URL', 'Scraped_At', 'Job_Type'],
#       dtype='object')

# %%
df = pd.read_csv(r'D:\DATA SCIENCE AND ML\Project\job_trend_predictor\etl_pipeline\data\raw\scraped_data.csv')

# %%
df.head()
# Out:
#                                     Title        Company    Experience  \
# 0                          Data Scientist  Deutsche Bank  4 - 13 years
# 1                          Data Scientist        Philips  6 - 11 years
# 2  Data Scientist-Artificial Intelligence            IBM   3 - 7 years
# 3                          Data Scientist         Alstom  7 - 12 years
# 4  Data Scientist-Artificial Intelligence            IBM   3 - 7 years
#
#           Salary   Location  \
# 0  Not Disclosed       Pune
# 1  Not Disclosed  Bengaluru
# 2  Not Disclosed  Hyderabad
# 3  Not Disclosed  Bengaluru
# 4  Not Disclosed  Bengaluru
#
#                                            Education         Star_Skills  \
# 0        EducationUG:Any GraduatePG:Any Postgraduate                  []
# 1        EducationUG:Any GraduatePG:Any Postgraduate                  []
# 2        EducationUG:Any GraduatePG:Any Postgraduate  ['data scientist']
# 3        EducationUG:Any GraduatePG:Any Postgraduate  ['data scientist']
# 4  EducationUG:Any GraduatePG:LLM in Law, Any Pos...  ['data scientist']
#
#                                        Normal_Skills Posted_Date  \
# 0  ['Data analysis', 'data science', 'Infrastruct...  2 days ago
# 1  ['Data analysis', 'SAP', 'Analytical', 'Health...  2 days ago
# 2  ['python', 'ai solutions', 'ai frameworks', 'a...       Today
# 3  ['python', 'neural networks', 'ai', 'numpy', '...  2 days ago
# 4  ['kubernetes', 'python', 'ai solutions', 'ai',...       Today
#
#   Last_Apply_Date                         Role                  Industry Type  \
# 0     09 Sep 2025              Data Engineer ,                      Banking ,
# 1     25 Jul 2024             Data Scientist ,  Medical Services / Hospital ,
# 2     19 Aug 2025             Data Scientist ,     IT Services & Consulting ,
# 3     09 Nov 2024  Full Stack Data Scientist ,              Urban Transport ,
# 4     19 Aug 2025  Full Stack Data Scientist ,     IT Services & Consulting ,
#
#                    Department       Employment Type  \
# 0  Data Science & Analytics ,  Full Time, Permanent
# 1  Data Science & Analytics ,  Full Time, Permanent
# 2  Data Science & Analytics ,  Full Time, Permanent
# 3  Data Science & Analytics ,  Full Time, Permanent
# 4  Data Science & Analytics ,  Full Time, Permanent
#
#                      Role Category  \
# 0  Data Science & Machine Learning
# 1  Data Science & Machine Learning
# 2  Data Science & Machine Learning
# 3  Data Science & Machine Learning
# 4  Data Science & Machine Learning
#
#                                          Description  \
# 0  The Deutsche India is seeking a talented Data ...
# 1  Job Title Data Scientist Job Description Data ...
# 2  As an Associate Data Scientist at IBM, you wil...
# 3  Your future role Take on a new challenge and a...
# 4  Scale an existing RAG code base for a producti...
#
#                                              Job_URL  \
# 0  https://www.naukri.com/job-listings-data-scien...
# 1  https://www.naukri.com/job-listings-data-scien...
# 2  https://www.naukri.com/job-listings-data-scien...
# 3  https://www.naukri.com/job-listings-data-scien...
# 4  https://www.naukri.com/job-listings-data-scien...
#
#                    Scraped_At        Job_Type
# 0  2025-12-03T21:54:40.504260  Data Scientist
# 1  2025-12-03T21:54:43.757232  Data Scientist
# 2  2025-12-03T21:54:47.228273  Data Scientist
# 3  2025-12-03T21:54:53.138785  Data Scientist
# 4  2025-12-03T21:54:59.775018  Data Scientist

# %%
df.tail(10)
# Out:
#                                   Title                          Company  \
# 14711           Ruby on Rails Developer                           Nomiso
# 14712  Ruby on Rails Developer - Hybrid                       Commutatus
# 14713   Ruby on Rails Developer (SDEII)                          Flexcar
# 14714           Ruby on Rails Developer                           Apptad
# 14715           Ruby on Rails Developer                       Commutatus
# 14716           Ruby on Rails developer             Bestpeers Infosystem
# 14717           Ruby on Rails Developer        Codecrux Web Technologies
# 14718           Ruby on Rails Developer                             Box8
# 14719           Ruby on Rails Developer               Paradesi Solutions
# 14720          Ruby On Rails Developers  Red Panthers Software Solutions
#
#          Experience         Salary                                  Location  \
# 14711  7 - 10 years  Not Disclosed                                 Hyderabad
# 14712   2 - 5 years  Not Disclosed                                 Bengaluru
# 14713   3 - 7 years  Not Disclosed                                 Bengaluru
# 14714   2 - 5 years  Not Disclosed  Hubli,Mangaluru,Mysuru,Bengaluru,Belgaum
# 14715   1 - 5 years  Not Disclosed                                    Remote
# 14716   1 - 4 years  Not Disclosed                                    Indore
# 14717  8 - 13 years  Not Disclosed                                 Hyderabad
# 14718   1 - 5 years  Not Disclosed                                 Bengaluru
# 14719   2 - 5 years  Not Disclosed                                 Hyderabad
# 14720   3 - 6 years  Not Disclosed                                     Kochi
#
#                                                Education  \
# 14711  EducationUG:B.Tech/B.E. in Production/Industri...
# 14712        EducationUG:Any GraduatePG:Any Postgraduate
# 14713        EducationUG:Any GraduatePG:Any Postgraduate
# 14714        EducationUG:Any GraduatePG:Any Postgraduate
# 14715        EducationUG:Any GraduatePG:Any Postgraduate
# 14716        EducationUG:Any GraduatePG:Any Postgraduate
# 14717        EducationUG:Any GraduatePG:Any Postgraduate
# 14718        EducationUG:Any GraduatePG:Any Postgraduate
# 14719  EducationUG:B.Tech/B.E. in Any SpecializationP...
# 14720  EducationUG:B.Tech/B.E. in ComputersPG:M.Tech ...
#
#                 Star_Skills  \
# 14711  ['Ruby Programming']
# 14712                    []
# 14713                    []
# 14714                    []
# 14715                    []
# 14716                    []
# 14717                    []
# 14718                    []
# 14719                    []
# 14720                    []
#
#                                            Normal_Skills   Posted_Date  \
# 14711  ['TypeScript', 'Ruby on Rails', 'Javascript', ...   2 weeks ago
# 14712  ['Computer science', 'Health insurance', 'gith...  3+ weeks ago
# 14713  ['css', 'bootstrap', 'ajax', 'jquery', 'redis'...  3+ weeks ago
# 14714  ['Team management', 'Ruby rails', 'Ruby on rai...  3+ weeks ago
# 14715  ['Computer science', 'Health insurance', 'gith...  3+ weeks ago
# 14716  ['css', 'c++', 'web application', 'vue.js', 'c...  3+ weeks ago
# 14717  ['Unix', 'jQuery', 'Linux', 'Coding', 'Configu...  3+ weeks ago
# 14718  ['Automation', 'Backend', 'Front end', 'GIT', ...  3+ weeks ago
# 14719  ['css', 'code versioning tools', 'bootstrap', ...  3+ weeks ago
# 14720  ['rest', 'github', 'Postgresql', 'test driven ...  3+ weeks ago
#
#       Last_Apply_Date                            Role  \
# 14711     03 Apr 2025          Full Stack Developer ,
# 14712     26 Jun 2024          Full Stack Developer ,
# 14713             NaN           Front End Developer ,
# 14714     16 May 2025           Front End Developer ,
# 14715     26 Jun 2024          Full Stack Developer ,
# 14716     15 Jun 2024           Front End Developer ,
# 14717             NaN          Full Stack Developer ,
# 14718     10 Jul 2025          Full Stack Developer ,
# 14719             NaN  Software Development - Other ,
# 14720             NaN            Back End Developer ,
#
#                     Industry Type                     Department  \
# 14711  IT Services & Consulting ,  Engineering - Software & QA ,
# 14712  IT Services & Consulting ,  Engineering - Software & QA ,
# 14713                Automobile ,  Engineering - Software & QA ,
# 14714  IT Services & Consulting ,  Engineering - Software & QA ,
# 14715  IT Services & Consulting ,  Engineering - Software & QA ,
# 14716  IT Services & Consulting ,  Engineering - Software & QA ,
# 14717  IT Services & Consulting ,  Engineering - Software & QA ,
# 14718           Food Processing ,  Engineering - Software & QA ,
# 14719     Management Consulting ,  Engineering - Software & QA ,
# 14720  IT Services & Consulting ,  Engineering - Software & QA ,
#
#             Employment Type         Role Category  \
# 14711  Full Time, Permanent  Software Development
# 14712  Full Time, Permanent  Software Development
# 14713  Full Time, Permanent  Software Development
# 14714  Full Time, Permanent  Software Development
# 14715  Full Time, Permanent  Software Development
# 14716  Full Time, Permanent  Software Development
# 14717  Full Time, Permanent  Software Development
# 14718  Full Time, Permanent  Software Development
# 14719  Full Time, Permanent  Software Development
# 14720  Full Time, Permanent  Software Development
#
#                                              Description  \
# 14711  Roles and Responsibilities : - Designing and d...
# 14712  You are open to working remotely. You have exc...
# 14713  We are looking for a skilled Ruby on Rails Dev...
# 14714  Candidate with 7+ years of experience. ~5 year...
# 14715  Ruby on Rails Developer - Remote at Commutatus...
# 14716  Design, build and maintain efficient, reusable...
# 14717  We are looking for a Ruby developer responsibl...
# 14718  Helping customers to find products they need. ...
# 14719  As a backend developer, you will be responsibl...
# 14720  We are looking ROR developers to build systems...
#
#                                                  Job_URL  \
# 14711  https://www.naukri.com/job-listings-ruby-on-ra...
# 14712  https://www.naukri.com/job-listings-ruby-on-ra...
# 14713  https://www.naukri.com/job-listings-ruby-on-ra...
# 14714  https://www.naukri.com/job-listings-ruby-on-ra...
# 14715  https://www.naukri.com/job-listings-ruby-on-ra...
# 14716  https://www.naukri.com/job-listings-ruby-on-ra...
# 14717  https://www.naukri.com/job-listings-ruby-on-ra...
# 14718  https://www.naukri.com/job-listings-ruby-on-ra...
# 14719  https://www.naukri.com/job-listings-ruby-on-ra...
# 14720  https://www.naukri.com/job-listings-ruby-on-ra...
#
#                        Scraped_At                 Job_Type
# 14711  2025-12-29T09:28:31.628679  Ruby on Rails Developer
# 14712  2025-12-29T09:28:37.024394  Ruby on Rails Developer
# 14713  2025-12-29T09:28:43.801279  Ruby on Rails Developer
# 14714  2025-12-29T09:28:49.743899  Ruby on Rails Developer
# 14715  2025-12-29T09:28:56.097584  Ruby on Rails Developer
# 14716  2025-12-29T09:28:59.405604  Ruby on Rails Developer
# 14717  2025-12-29T09:29:05.186656  Ruby on Rails Developer
# 14718  2025-12-29T09:29:11.179514  Ruby on Rails Developer
# 14719  2025-12-29T09:29:15.756483  Ruby on Rails Developer
# 14720  2025-12-29T09:29:19.288707  Ruby on Rails Developer

# %%
df.loc[1300:1305]
# Out:
#                                                   Title  \
# 1300                                  Software Engineer
# 1301                                                NaN
# 1302                                  Software Engineer
# 1303                                  Software Engineer
# 1304  Software Engineer Trainee | Walk-in | Male Can...
# 1305                                  Software Engineer
#
#                          Company   Experience         Salary  \
# 1300                         KLA  2 - 3 years  Not Disclosed
# 1301                         NaN          NaN            NaN
# 1302  Hewlett Packard Enterprise  3 - 5 years  Not Disclosed
# 1303                  Altisource  0 - 5 years  Not Disclosed
# 1304                  Soft Suave      0 years  3-4 Lacs P.A.
# 1305                     Alteryx  3 - 8 years  Not Disclosed
#
#                 Location                                      Education  \
# 1300             Chennai    EducationUG:Any GraduatePG:Any Postgraduate
# 1301                 NaN                                  Not Available
# 1302           Bengaluru    EducationUG:Any GraduatePG:Any Postgraduate
# 1303           Bengaluru    EducationUG:Any GraduatePG:Any Postgraduate
# 1304  Chennai( Navalur )  EducationUG:B.Tech/B.E. in Any Specialization
# 1305           Bengaluru    EducationUG:Any GraduatePG:Any Postgraduate
#
#                    Star_Skills  \
# 1300                        []
# 1301                        []
# 1302                        []
# 1303                        []
# 1304  ['Software Development']
# 1305                        []
#
#                                           Normal_Skills Posted_Date  \
# 1300  ['Computer science', 'Coding', 'Chip design', ...   1 day ago
# 1301                                                 []         NaN
# 1302  ['TCP', 'Computer science', 'Product quality',...       Today
# 1303  ['Computer science', 'jQuery', 'Coding', 'MySQ...  1 week ago
# 1304                                 ['Java', 'Python']  2 days ago
# 1305  ['Software design', 'Operating systems', 'Comp...       Today
#
#      Last_Apply_Date                            Role  \
# 1300     29 Nov 2023            Back End Developer ,
# 1301             NaN                             NaN
# 1302     07 Jan 2025            Back End Developer ,
# 1303     15 Oct 2024          Full Stack Developer ,
# 1304             NaN  Software Development - Other ,
# 1305             NaN  Software Development - Other ,
#
#                                  Industry Type                     Department  \
# 1300  Electronic Components / Semiconductors ,  Engineering - Software & QA ,
# 1301                                       NaN                            NaN
# 1302                IT Services & Consulting ,  Engineering - Software & QA ,
# 1303                             Real Estate ,  Engineering - Software & QA ,
# 1304                IT Services & Consulting ,  Engineering - Software & QA ,
# 1305                        Software Product ,  Engineering - Software & QA ,
#
#            Employment Type         Role Category  \
# 1300  Full Time, Permanent  Software Development
# 1301                   NaN                   NaN
# 1302  Full Time, Permanent  Software Development
# 1303  Full Time, Permanent  Software Development
# 1304  Full Time, Permanent  Software Development
# 1305  Full Time, Permanent  Software Development
# 13999                                                 []
# 14000  ['Java', 'Amazon Ec2', 'Aws Lambda', 'Node.Js'...
#
#                                            Normal_Skills  Posted_Date  \
# 13095  ['Functional analysis design and articheture',...    1 day ago
# 13096  ['product strategy', 'project management', 'pr...  2 weeks ago
# 13097  ['Secured Loan', 'DST', 'Bl', 'Retail Assets',...        Today
# 13098  ['Product Strategy', 'Product Roadmap', 'Produ...    1 day ago
# 13099  ['Product Strategy', 'End To End Project Manag...   4 days ago
# ...                                                  ...          ...
# 13996  ['continuous integration', 'software developme...   1 week ago
# 13997  ['redux', 'css', 'hibernate', 'docker', 'micro...   1 week ago
# 13998  ['Computer science', 'Hibernate', 'Backend', '...   4 days ago
# 13999  ['Backend', 'Front end', 'Web technologies', '...   4 days ago
# 14000  ['Typescript', 'Javascript', 'React.Js', 'Angu...   1 week ago
#
#       Last_Apply_Date                       Role               Industry Type  \
# 13095             NaN          Finance - Other ,    Recruitment / Staffing ,
# 13096     20 Feb 2025          Product Manager ,  IT Services & Consulting ,
# 13097     04 Oct 2024  Product Manager - Loans ,                   Banking ,
# 13098     12 Nov 2024          Product Manager ,  IT Services & Consulting ,
# 13099             NaN          Product Manager ,             Miscellaneous ,
# ...               ...                        ...                         ...
# 13996     29 May 2024     Full Stack Developer ,                     Power ,
# 13997     04 Aug 2024     Full Stack Developer ,        Financial Services ,
# 13998             NaN     Full Stack Developer ,          Software Product ,
# 13999     08 Jan 2025     Full Stack Developer ,                 BPM / BPO ,
# 14000     26 Jan 2025                    Other ,  IT Services & Consulting ,
#
#                           Department       Employment Type  \
# 13095         Finance & Accounting ,  Full Time, Permanent
# 13096           Product Management ,  Full Time, Permanent
# 13097           Product Management ,  Full Time, Permanent
# 13098           Product Management ,  Full Time, Permanent
# 13099           Product Management ,  Full Time, Permanent
# ...                              ...                   ...
# 13996  Engineering - Software & QA ,  Full Time, Permanent
# 13997  Engineering - Software & QA ,  Full Time, Permanent
# 13998  Engineering - Software & QA ,  Full Time, Permanent
# 13999  Engineering - Software & QA ,  Full Time, Permanent
# 14000                        Other ,  Full Time, Permanent
#
#                          Role Category  \
# 13095                          Finance
# 13096  Product Management - Technology
# 13097       Product Management - Other
# 13098  Product Management - Technology
# 13099  Product Management - Technology
# ...                                ...
# 13996             Software Development
# 13997             Software Development
# 13998             Software Development
# 13999             Software Development
# 14000                            Other
#
#                                              Description  \
# 13095  Product Manager 603 As a Product Manager in [I...
# 13096  We are looking for a skilled Product Manager w...
# 13097  Job Description: Product Manager  Secured Busi...
# 13098  Key Responsibilities: Define and drive the pro...
# 13099  At IncrediPets , we combine deep consumer unde...
# ...                                                  ...
# 13996  ExxonMobil India Careers is looking for Full S...
# 13997  Join us as a Software Engineer at Barclays, re...
# 13998  We are seeking a skilled Full Stack Developer ...
# 13999  We are looking for a skilled Full Stack Develo...
# 14000  Roles and Responsibilities Design, develop, te...
#
#                                                  Job_URL  \
# 13095  https://www.naukri.com/job-listings-product-ma...
# 13096  https://www.naukri.com/job-listings-product-ma...
# 13097  https://www.naukri.com/job-listings-product-ma...
# 13098  https://www.naukri.com/job-listings-product-ma...
# 13099  https://www.naukri.com/job-listings-product-ma...
# ...                                                  ...
# 13996  https://www.naukri.com/job-listings-full-stack...
# 13997  https://www.naukri.com/job-listings-full-stack...
# 13998  https://www.naukri.com/job-listings-full-stack...
# 13999  https://www.naukri.com/job-listings-full-stack...
# 14000  https://www.naukri.com/job-listings-aws-full-s...
#
#                        Scraped_At              Job_Type
# 13095  2025-12-20T22:08:49.758573       Product Manager
# 13096  2025-12-20T22:08:53.916745       Product Manager
# 13097  2025-12-20T22:08:58.551161       Product Manager
# 13098  2025-12-20T22:09:03.720739       Product Manager
# 13099  2025-12-20T22:09:14.271750       Product Manager
# ...                           ...                   ...
# 13996  2025-12-28T22:11:53.919055  Full Stack Developer
# 13997  2025-12-28T22:11:58.331135  Full Stack Developer
# 13998  2025-12-28T22:12:04.398940  Full Stack Developer
# 13999  2025-12-28T22:12:08.775481  Full Stack Developer
# 14000  2025-12-28T22:12:15.433192  Full Stack Developer
#
# [906 rows x 19 columns]

# %%
# df.loc[14000:14005]
df.loc[14003:14008]
# Out:
#                          Title              Company     Experience  \
# 14003       GCP Cloud Engineer             Noventiq    1 - 3 years
# 14004           Cloud Engineer                NOVAC    2 - 4 years
# 14005           Cloud Engineer            Capgemini    3 - 6 years
# 14006  Gulf: Cloud Engineer x8  Spectrum Consulting   5 - 10 years
# 14007       GCP Cloud Engineer               Zarthi    1 - 2 years
# 14008    Cloud Native Engineer            Accenture  12 - 15 years
#
#                 Salary                            Location  \
# 14003    Not Disclosed                               Noida
# 14004    Not Disclosed                 Chennai( Alwarpet )
# 14005    Not Disclosed         Hyderabad,Chennai,Bengaluru
# 14006  20-35 Lacs P.A.            Hyderabad,Pune,Bengaluru
# 14007    Not Disclosed  Noida,Bengaluru,Thiruvananthapuram
# 14008    Not Disclosed                           Bengaluru
#
#                                                Education  \
# 14003                           EducationUG:Any Graduate
# 14004                           EducationUG:Any Graduate
# 14005                           EducationUG:Any Graduate
# 14006                           EducationUG:Any Graduate
# 14007                           EducationUG:Any Graduate
# 14008  EducationUG:B.Tech/B.E. in Any SpecializationP...
#
#                                              Star_Skills  \
# 14003                               ['GCP Cloud', 'GCP']
# 14004         ['Azure Cloud', 'GCP', 'Azure Databricks']
# 14005                    ['Azure', 'GCP', 'Azure Cloud']
# 14006  ['Ci/Cd', 'Jenkins', 'Terraform', 'Ansible', '...
# 14007                                  ['GCP', 'Devops']
# 14008  ['kubernetes', 'continuous integration', 'dock...
#
#                                            Normal_Skills Posted_Date  \
# 14003                                  ['Cloud Storage']  4 days ago
# 14004  ['Backup', 'Azure Vm', 'Azure Networking', 'Di...  5 days ago
# 14005                        ['Azure Cli', 'Powershell']  6 days ago
# 14006  ['Github', 'Powershell', 'Devops', 'Docker', '...  6 days ago
# 14007  ['Design', 'Docker', 'Cloud', 'Ci/Cd', 'Google...  1 week ago
# 14008  ['ci/cd', 'ansible', 'microservices', 'contain...  6 days ago
#
#       Last_Apply_Date                                               Role  \
# 14003     22 Apr 2025  Role & responsibilities Provide Technical Supp...
# 14004     18 Jul 2025  Role & responsibilities: Design, implement, an...
# 14005     05 Feb 2025  Given your work experience, we believe it woul...
# 14006     04 Apr 2025  Job Title: Cloud Engineer Job Location: -- Mul...
# 14007     23 Aug 2025  Role & responsibilities Architect  & Deploy GC...
# 14008     25 Mar 2025  About The Role Project Role : Cloud Native Eng...
# 14019          Wissen Technology   5 - 10 years  Not Disclosed
# 14020  Tata Consultancy Services  10 - 15 years  Not Disclosed
#
#                           Location  \
# 14010                    Bengaluru
# 14011                    Bengaluru
# 14012                    Bengaluru
# 14013                    Bengaluru
# 14014                    Bengaluru
# 14015                    Bengaluru
# 14016                      Chennai
# 14017                    Bengaluru
# 14018            Kolkata( Tangra )
# 14019                       Mumbai
# 14020  Hyderabad,Chennai,Bengaluru
#
#                                                Education  \
# 14010  EducationUG:B.Tech/B.E. in Any SpecializationP...
# 14011  EducationUG:B.Tech/B.E. in Any SpecializationP...
# 14012  EducationUG:B.Tech/B.E. in Any SpecializationP...
# 14013  EducationUG:B.Tech/B.E. in Any SpecializationP...
# 14014  EducationUG:B.Tech/B.E. in Any SpecializationP...
# 14015  EducationUG:B.Tech/B.E. in Any SpecializationP...
# 14016  EducationUG:B.Tech/B.E. in Any SpecializationP...
# 14017  EducationUG:B.Tech/B.E. in Production/Industri...
# 14018                           EducationUG:Any Graduate
# 14019                           EducationUG:Any Graduate
# 14020                           EducationUG:Any Graduate
#
#                                              Star_Skills  \
# 14010  ['amazon lex', 'aws lambda', 'stakeholder mana...
# 14011  ['amazon lex', 'aws lambda', 'stakeholder mana...
# 14012  ['amazon lex', 'aws lambda', 'stakeholder mana...
# 14013  ['amazon lex', 'aws lambda', 'stakeholder mana...
# 14014  ['amazon lex', 'aws lambda', 'stakeholder mana...
# 14015  ['amazon lex', 'aws lambda', 'stakeholder mana...
# 14016                                 ['cloud engineer']
# 14017  ['c++', 'python', 'kernel', 'linux', 'software...
# 14018                         ['Linux', 'Github', 'AWS']
# 14019                                                 []
# 14020                                            ['GCP']
#
#                                            Normal_Skills  Posted_Date  \
# 14010  ['continuous integration', 'python', 'api gate...   6 days ago
# 14011  ['continuous integration', 'python', 'api gate...   6 days ago
# 14012  ['kubernetes', 'continuous integration', 'pyth...   6 days ago
# 14013  ['kubernetes', 'continuous integration', 'pyth...   6 days ago
# 14014  ['continuous integration', 'python', 'api gate...   6 days ago
# 14015  ['continuous integration', 'python', 'api gate...   6 days ago
# 14016  ['insurance', 'kubernetes', 'application devel...   4 days ago
# 14017  ['kernel mode driver programming', 'software t...   6 days ago
# 14018                                                 []   1 week ago
# 14019  ['kubernetes', 'iac', 'java coding', 'docker',...   5 days ago
# 14020  ['Vertex', 'Terraform', 'Ai Platform', 'Kubern...  2 weeks ago
#
#       Last_Apply_Date                                               Role  \
# 14010     25 Mar 2025  About The Role Project Role : Cloud Native Eng...
# 14011     25 Mar 2025  About The Role Project Role : Cloud Native Eng...
# 14012     25 Mar 2025  About The Role Project Role : Cloud Native Eng...
# 14013     25 Mar 2025  About The Role Project Role : Cloud Native Eng...
# 14014     25 Mar 2025  About The Role Project Role : Cloud Native Eng...
# 14015     25 Mar 2025  About The Role Project Role : Cloud Native Eng...
# 14016     04 Sep 2025  Position Purpose As part of our transformation...
# 14017     27 Nov 2025  General Summary: Qualcomm Cloud Team is lookin...
# 14018     13 Dec 2024  We are seeking a skilled AWS Cloud Engineer to...
# 14019     15 Oct 2025  SUMMARY Wissen Technology is Hirin g for Cloud...
# 14020     19 Nov 2025  Greetings from Tata Consultancy Services (TCS)...
#
#                                            Industry Type  \
# 14010  https://www.naukri.com/job-listings-cloud-nati...
# 14011  https://www.naukri.com/job-listings-cloud-nati...
# 14012  https://www.naukri.com/job-listings-cloud-nati...
# 14013  https://www.naukri.com/job-listings-cloud-nati...
# 14014  https://www.naukri.com/job-listings-cloud-nati...
# 14015  https://www.naukri.com/job-listings-cloud-nati...
# 14016  https://www.naukri.com/job-listings-cloud-engi...
# 14017  https://www.naukri.com/job-listings-engineer-c...
# 14018  https://www.naukri.com/job-listings-cloud-engi...
# 14019  https://www.naukri.com/job-listings-cloud-engi...
# 14020  https://www.naukri.com/job-listings-hiirng-for...
#
#                        Department Employment Type  \
# 14010  2025-12-28T22:14:42.182573  Cloud Engineer
# 14011  2025-12-28T22:14:45.941083  Cloud Engineer
# 3168    2 - 4 years       Not Disclosed
# 6972    1 - 2 years       Not Disclosed
# 6857        0 years       Not Disclosed
# 2541   5 - 10 years       Not Disclosed
#
#                                                 Location  \
# 12079              Mumbai,Navi Mumbai,Mumbai (All Areas)
# 2740                                           Bengaluru
# 13172                                            Lucknow
# 1610                                                Pune
# 7943                                                Pune
# 13989                                             Remote
# 3168                                           Hyderabad
# 6972   Kolkata,Mumbai,New Delhi,Hyderabad,Pune,Chenna...
# 6857                                           New Delhi
# 2541                            Hyderabad,Pune,Bengaluru
#
#                                                Education  \
# 12079                           EducationUG:Any Graduate
# 2740   EducationUG:B.Tech/B.E. in Any SpecializationP...
# 13172                           EducationUG:Any Graduate
# 1610         EducationUG:Any GraduatePG:Any Postgraduate
# 7943         EducationUG:Any GraduatePG:Any Postgraduate
# 13989        EducationUG:Any GraduatePG:Any Postgraduate
# 3168                            EducationUG:Any Graduate
# 6972         EducationUG:Any GraduatePG:Any Postgraduate
# 6857                EducationUG:B.Tech/B.E. in Computers
# 2541       EducationUG:B.Tech/B.E. in Any Specialization
#
#                                              Star_Skills  \
# 12079          ['Database Administration', 'Postgresql']
# 2740                                   ['data engineer']
# 13172  ['Shopify Plus', 'Shopify Customization', 'Sho...
# 1610                                                  []
# 7943                                                  []
# 13989                                                 []
# 3168                                                  []
# 6972                                                  []
# 6857                       ['Linux', 'Django', 'Python']
# 2541   ['ML Engineer', 'Microsoft Azure', 'Azure Mach...
#
#                                            Normal_Skills   Posted_Date  \
# 12079  ['Cloud Sql', 'Postgres Database', 'Postgresql...    1 week ago
# 2740   ['python', 'data pipelines', 'data validation'...    2 days ago
# 13172  ['Ecommerce Marketing', 'Website Management', ...    2 days ago
# 1610   ['cloud security', 'Architecture', 'GCP', 'Clo...    1 week ago
# 7943   ['Basic', 'Publishing', 'Mobile development', ...  3+ weeks ago
# 13989  ['jQuery', 'Front end', 'Version control', 'GI...    4 days ago
# 3168   ['container', 'continuous integration', 'kuber...         Today
# 6972   ['Basic', 'jQuery', 'Front end', 'GIT', 'html5...  3+ weeks ago
# 6857                   ['Vue.Js', 'Postgresql', 'MySQL']    3 days ago
# 2541                   ['Artificial Intelligence', 'Ml']    1 week ago
#
#       Last_Apply_Date                                               Role  \
# 12079             NaN                           Database Administrator ,
# 2740      11 Nov 2025                                    Data Engineer ,
# 13172   91 92609 6889       Other Program / Project Management - Other ,
# 1610      16 Jul 2025                      Cloud System Administration ,
# 7943      18 Jun 2025                           Mobile / App Developer ,
# 13989     23 Dec 2024                             Full Stack Developer ,
# 3168      30 Apr 2024                                  DevOps Engineer ,
# 6972              NaN                     Software Development - Other ,
# 6857      28 May 2025                     Software Development - Other ,
# 2541              NaN  Project Role : Custom Software Engineer Must h...
#
#                                            Industry Type  \
# 12079                         IT Services & Consulting ,
# 2740                          IT Services & Consulting ,
# 13172      Advertising & Marketing (Digital Marketing) ,
# 1610                          IT Services & Consulting ,
# 7943                          IT Services & Consulting ,
# 13989                         IT Services & Consulting ,
# 3168                          IT Services & Consulting ,
# 6972                          IT Services & Consulting ,
# 6857                          IT Services & Consulting ,
# 2541   https://www.naukri.com/job-listings-microsoft-...
#
#                            Department            Employment Type  \
# 12079   Engineering - Software & QA ,       Full Time, Permanent
# 2740    Engineering - Software & QA ,       Full Time, Permanent
# 13172  Project & Program Management ,       Full Time, Permanent
# 1610      IT & Information Security ,       Full Time, Permanent
# 7943    Engineering - Software & QA ,       Full Time, Permanent
# 13989   Engineering - Software & QA ,       Full Time, Permanent
# 3168    Engineering - Software & QA ,       Full Time, Permanent
# 6972    Engineering - Software & QA ,       Full Time, Permanent
# 6857    Engineering - Software & QA ,       Full Time, Permanent
# 2541       2025-12-12T22:18:49.620143  Machine Learning Engineer
#
#                             Role Category  \
# 12079              DBA / Data warehousing
# 2740                 Software Development
# 13172  Other Program / Project Management
# 1610           IT Infrastructure Services
# 7943                 Software Development
# 13989                Software Development
# 3168                               DevOps
# 6972                 Software Development
# 6857                 Software Development
# 2541       Software Development - Other ,
#
#                                              Description  \
# 12079  PostgreSQL DBA with focusing on our cloud envi...
# 2740   Roles and Responsibility Design, develop, and ...
# 13172  Job Title : Project Manager / Shopify Success ...
# 1610   Skills Required: AWS/Azure/GCP, Cloud Architec...
# 7943   Develop, test, and maintain mobile application...
# 13989  We are looking for a Full Stack Developer who ...
# 3168   Role Overview We are looking for a motivated D...
# 6972   Primary Skills : Ruby, ROR, OOPs, Java script,...
# 6857   Responsibilities: Writing back-end code and bu...
# 2541                          IT Services & Consulting ,
#
#                                                  Job_URL  \
# 12079  https://www.naukri.com/job-listings-database-a...
# 2740   https://www.naukri.com/job-listings-data-engin...
# 13172  https://www.naukri.com/job-listings-project-ma...
# 1610   https://www.naukri.com/job-listings-cloud-engi...
# 7943   https://www.naukri.com/job-listings-mobile-app...
# 13989  https://www.naukri.com/job-listings-full-stack...
# 3168   https://www.naukri.com/job-listings-devops-eng...
# 6972   https://www.naukri.com/job-listings-ruby-on-ra...
# 6857   https://www.naukri.com/job-listings-urgent-ope...
# 2541                       Engineering - Software & QA ,
#
#                        Scraped_At                 Job_Type
# 12079  2025-12-19T21:54:32.969456   Database Administrator
# 2740   2025-12-12T22:44:32.453890            Data Engineer
# 13172  2025-12-20T22:16:56.691318          Project Manager
# 1610   2025-12-12T00:01:50.183007           Cloud Engineer
# 7943   2025-12-15T21:45:41.999824     Mobile App Developer
# 13989  2025-12-28T22:11:18.148348     Full Stack Developer
# 3168   2025-12-12T23:37:05.275471        DevOps Specialist
# 6972   2025-12-14T23:57:58.211554  Ruby on Rails Developer
# 6857   2025-12-14T23:44:44.673446         Python Developer
# 2541         Full Time, Permanent     Software Development

# %%
problem in Title column:
1. Technical Writer , Technical writer - Cisco Tech Comms , Technical Writer Operations , Research Analyst / Technical Writer
2. Hiring for Python Developer , Python Developer
3. Clin Project Manager , Project Manager
5. Azure Data Scientist (AI & ML) , Data Scientist, Data Scientist-Artificial Intelligence	
6. Gulf: Cloud Engineer x8 , Cloud Engineer , Cloude Native Engineer
7. Custom Software Engineer	 , Software Engineer
8., Data Analyst , Business 



My approach to solve this problem :
Create list of common job title alread there in config file 
Map the job titles in the dataframe to the common job titles using fuzzy matching
# Out:
#   Cell In[10], line 1
#     problem in Title column:
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# Problem in Company Column :
# Extra posted by string
#
# Solution : remove it
#
# problem in Experience : format 2 - 5 years
# solution change col name to experience(in years)
#
# Problem in Salary:
# salary format - 25-37.5 Lacs P.A.
# solution : remove Lacs(P.A)
# change colname to Lacs(P.A)
#
# Problem in Location:
# there are both single location and multiple loaction
# solution: store location in list format

# %%
print(df["Education"].sample(1))
# Out:
# 8606    EducationUG:Any GraduatePG:Any Postgraduate
# Name: Education, dtype: object

# %% [markdown]
# Problem in Education:
# format :  EducationUG:Any GraduatePG:Any Postgraduate
# solution : make a orderd list of eduction

# %%
df["Star_Skills"].sample(10)
# Out:
# 9480     ['GIT', 'back end developer', 'full stack deve...
# 5243                                            ['Python']
# 4317                                                    []
# 5583                                     ['web developer']
# 7441                                   ['devops engineer']
# 1530     ['Figma', 'Wireframing', 'Adobe Xd', 'Prototyp...
# 11310                                                   []
# 9621                                                    []
# 11320                                                   []
# 9247                               ['Application Support']
# Name: Star_Skills, dtype: object

# %%
df["Normal_Skills"].sample(10)
# Out:
# 6082     ['Cold calling', 'Product management', 'Costin...
# 789      ['Business Planning Strategy', 'Business Analy...
# 9825     ['generative ai', 'devops', 'design', 'ai', 'm...
# 10900    ['kubernetes', 'data pipelines', 'fintech', 's...
# 7084     ['data analytics', 'Data Visualization', 'Tabl...
# 13140    ['RTOS', 'Cloud Technologies', 'Hardware', 'Em...
# 13252    ['Automation', 'Database design', 'Enterprise ...
# 7447     ['continuous integration', 'board support pack...
# 10903                              ['Azure', 'GCP', 'AWS']
# 14312    ['FMCG Marketing', 'Malayalam', 'Marathi', 'Ta...
# Name: Normal_Skills, dtype: object

# %%
Problem : 
some Star_Skills are empty

Solution : merge star_list and Noramal_skills and create single column which contain list of skills

# %% [markdown]
# Just now , Few hours ago , 3+ weeks ago
#
# 24 Sep 2025	 , Nan

# %%
print(df["Role"].sample(1))
# Out:
# 1997    Network (Support) Engineer ,
# Name: Role, dtype: object

# %% [markdown]
# Software Development - Other ,
# About The Role Project Role : Business Analyst..

# %%
df[["Industry Type"	,"Department"	,"Employment Type"	,"Role Category"]].sample(10)
# Out:
#                                        Industry Type  \
# 13789                     IT Services & Consulting ,
# 3447                         Accounting / Auditing ,
# 3754                      IT Services & Consulting ,
# 10648                     IT Services & Consulting ,
# 5902                      IT Services & Consulting ,
# 6214   Advertising & Marketing (Digital Marketing) ,
# 7852                      IT Services & Consulting ,
# 12003                           Financial Services ,
# 324             Automobile (Electric Vehicle (EV)) ,
# 14641                     IT Services & Consulting ,
#
#                                 Department       Employment Type  \
# 13789        Engineering - Software & QA ,  Full Time, Permanent
# 3447         Engineering - Software & QA ,  Full Time, Permanent
# 3754         Engineering - Software & QA ,  Full Time, Permanent
# 10648        Engineering - Software & QA ,  Full Time, Permanent
# 5902           IT & Information Security ,  Full Time, Permanent
# 6214         Engineering - Software & QA ,  Full Time, Permanent
# 7852   Engineering - Hardware & Networks ,  Full Time, Permanent
# 12003        Engineering - Software & QA ,  Full Time, Permanent
# 324          Engineering - Software & QA ,  Full Time, Permanent
# 14641        Engineering - Software & QA ,  Full Time, Permanent
#
#                            Role Category
# 13789                             DevOps
# 3447                Software Development
# 3754                Software Development
# 10648      Quality Assurance and Testing
# 5902   IT & Information Security - Other
# 6214                Software Development
# 7852                          IT Network
# 12003                             DevOps
# 324                 Software Development
# 14641               Software Development

# %% [markdown]
# Industry Type :
# /  ,
# in some column there is linke like https://www.naukri.com/job-listings-machine-le...
# remove , / and create list of Industry Type
#
# Department:
# formate sample :  Engineering - Software & QA ,Data Science & Analytics ,
# actionable - remove - and concante by _ , make list of department by striping through , symbol

# %%
# quick_detect.py

import pandas as pd
import re
from datetime import datetime

# Load your data


print("🔍 Quick Column Shift Detection\n")

# 1. Find future dates in Last_Apply_Date
print("1️⃣ Checking for future dates...")
if 'Last_Apply_Date' in df.columns:
    def is_future_date(val):
        try:
            date = datetime.strptime(str(val).strip(), '%d %b %Y')
            return date > datetime.now()
        except:
            return False
    
    future_dates = df[df['Last_Apply_Date'].apply(is_future_date)]
    print(f"   Found {len(future_dates)} rows with future dates")
    if not future_dates.empty:
        print(f"   Row indices: {future_dates.index.tolist()[:20]}...")  # First 20

# 2. Find dates in Salary column
print("\n2️⃣ Checking for dates in Salary column...")
date_pattern = r'\d{1,2}\s+(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)\s+\d{4}'
if 'Salary' in df.columns:
    dates_in_salary = df[df['Salary'].astype(str).str.contains(date_pattern, regex=True, na=False)]
    print(f"   Found {len(dates_in_salary)} rows with dates in Salary")
    if not dates_in_salary.empty:
        print(f"   Row indices: {dates_in_salary.index.tolist()[:20]}...")

# 3. Find "Other" duplication in Industry_Type
print("\n3️⃣ Checking for malformed Industry_Type...")
if 'Industry_Type' in df.columns:
    malformed = df[df['Industry_Type'].astype(str).str.contains(r'Other.*,.*Other', regex=True, na=False)]
    print(f"   Found {len(malformed)} rows with duplicate 'Other'")
    if not malformed.empty:
        print(f"   Row indices: {malformed.index.tolist()[:20]}...")

# 4. Combine all affected rows
all_affected = set()
if 'Last_Apply_Date' in df.columns:
    all_affected.update(future_dates.index.tolist())
if 'Salary' in df.columns:
    all_affected.update(dates_in_salary.index.tolist())
if 'Industry_Type' in df.columns:
    all_affected.update(malformed.index.tolist())

print(f"\n🎯 TOTAL AFFECTED ROWS: {len(all_affected)} out of {len(df)}")
print(f"   Percentage: {len(all_affected)/len(df)*100:.2f}%")

# Save affected rows
if all_affected:
    affected_df = df.loc[list(all_affected)]
    affected_df.to_csv("data/reports/problematic_rows.csv", index=True)
    print(f"\n💾 Saved problematic rows to: data/reports/problematic_rows.csv")
# Out:
# 🔍 Quick Column Shift Detection
#
# 1️⃣ Checking for future dates...
#    Found 0 rows with future dates
#
# 2️⃣ Checking for dates in Salary column...
#    Found 0 rows with dates in Salary
#
# 3️⃣ Checking for malformed Industry_Type...
#
# 🎯 TOTAL AFFECTED ROWS: 0 out of 14721
#    Percentage: 0.00%
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_14960\2973483959.py:31: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   dates_in_salary = df[df['Salary'].astype(str).str.contains(date_pattern, regex=True, na=False)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14721 entries, 0 to 14720
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            14644 non-null  object
#  1   Company          14547 non-null  object
#  2   Experience       14644 non-null  object
#  3   Salary           14644 non-null  object
#  4   Location         14644 non-null  object
#  5   Education        14721 non-null  object
#  6   Star_Skills      14721 non-null  object
#  7   Normal_Skills    14721 non-null  object
#  8   Posted_Date      14648 non-null  object
#  9   Last_Apply_Date  10603 non-null  object
#  10  Role             14644 non-null  object
#  11  Industry Type    14655 non-null  object
#  12  Department       14655 non-null  object
#  13  Employment Type  14655 non-null  object
#  14  Role Category    14644 non-null  object
#  15  Description      14644 non-null  object
#  16  Job_URL          14710 non-null  object
#  17  Scraped_At       14710 non-null  object
#  18  Job_Type         14710 non-null  object
# dtypes: object(19)
# memory usage: 2.1+ MB

# %%
type(df["Description"][0])
# Out:
# str

# %%
import re
from datetime import datetime

# %%
def is_description(description: str) -> bool:
    """
    Validate if string is a valid job description
    
    Expected: Long text (200-5000 chars), multiple sentences
    
    Args:
        description: String to validate
        
    Returns:
        True if valid description, False otherwise
    """
    if not isinstance(description, str):
        return False
    
    # Check if "NA" or empty
    if description.strip().upper() in ['NA', 'N/A', 'NOT AVAILABLE', '']:
        return False
    
    # Should NOT be a URL (catch misalignment)
    if description.startswith('http'):
        return False
    
    # Should NOT look like a timestamp
    if re.match(r'\d{4}-\d{2}-\d{2}', description[:10]):
        return False
    return True



def is_job_url(job_url: str) -> bool:
    """
    Validate if string is a valid job URL
    
    Expected: Naukri.com job URLs
    
    Args:
        job_url: String to validate
        
    Returns:
        True if valid URL, False otherwise
    """
    if not isinstance(job_url, str):
        return False
    
    # Remove whitespace
    job_url = job_url.strip()
    
    # Check basic URL structure
    url_pattern = r'^https?://(www\.)?naukri\.com/.+$'
    
    if not re.match(url_pattern, job_url, re.IGNORECASE):
        return False
    
    # Additional checks
    if len(job_url) < 30:  # URLs are typically longer
        return False
    
    if ' ' in job_url:  # URLs shouldn't have spaces
        return False
    
    return True
    


from datetime import datetime

# %%
for description in df["Description"]:
    if not is_description(description):
        print(is_description(description))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for description in df["Description"]:
#       2     if not is_description(description):
#       3         print(is_description(description))
#
# NameError: name 'df' is not defined

# %%
for url in df["Job_URL"]:
    if not is_job_url(url):
        print(is_job_url(url))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for url in df["Job_URL"]:
#       2     if not is_job_url(url):
#       3         print(is_job_url(url))
#
# NameError: name 'df' is not defined

# %%
for time in df["Scraped_At"]:
    if not is_timestamp(time):
        print(time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for time in df["Scraped_At"]:
#       2     if not is_timestamp(time):
#       3         print(time)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Data Cleaning

# %%
import pandas as pd
import re

# %%
df = pd.read_csv(r"D:\DATA SCIENCE AND ML\Project\job_trend_predictor\data\processed\validated\jobs_validated_20260107_095333.csv")

# %%
df
# Out:
#                                         Title  \
# 0                              Data Scientist
# 1                              Data Scientist
# 2      Data Scientist-Artificial Intelligence
# 3                              Data Scientist
# 4      Data Scientist-Artificial Intelligence
# ...                                       ...
# 14420                 Ruby on Rails developer
# 14421                 Ruby on Rails Developer
# 14422                 Ruby on Rails Developer
# 14423                 Ruby on Rails Developer
# 14424                Ruby On Rails Developers
#
#                                Company    Experience         Salary  \
# 0                        Deutsche Bank  4 - 13 years  Not Disclosed
# 1                              Philips  6 - 11 years  Not Disclosed
# 2                                  IBM   3 - 7 years  Not Disclosed
# 3                               Alstom  7 - 12 years  Not Disclosed
# 4                                  IBM   3 - 7 years  Not Disclosed
# ...                                ...           ...            ...
# 14420             Bestpeers Infosystem   1 - 4 years  Not Disclosed
# 14421        Codecrux Web Technologies  8 - 13 years  Not Disclosed
# 14422                             Box8   1 - 5 years  Not Disclosed
# 14423               Paradesi Solutions   2 - 5 years  Not Disclosed
# 14424  Red Panthers Software Solutions   3 - 6 years  Not Disclosed
#
#         Location                                          Education  \
# 0           Pune        EducationUG:Any GraduatePG:Any Postgraduate
# 1      Bengaluru        EducationUG:Any GraduatePG:Any Postgraduate
# 2      Hyderabad        EducationUG:Any GraduatePG:Any Postgraduate
# 3      Bengaluru        EducationUG:Any GraduatePG:Any Postgraduate
# 4      Bengaluru  EducationUG:Any GraduatePG:LLM in Law, Any Pos...
# ...          ...                                                ...
# 14420     Indore        EducationUG:Any GraduatePG:Any Postgraduate
# 14421  Hyderabad        EducationUG:Any GraduatePG:Any Postgraduate
# 14422  Bengaluru        EducationUG:Any GraduatePG:Any Postgraduate
# 14423  Hyderabad  EducationUG:B.Tech/B.E. in Any SpecializationP...
# 14424      Kochi  EducationUG:B.Tech/B.E. in ComputersPG:M.Tech ...
#
#               Star_Skills                                      Normal_Skills  \
# 0                      []  ['Data analysis', 'data science', 'Infrastruct...
# 1                      []  ['Data analysis', 'SAP', 'Analytical', 'Health...
# 2      ['data scientist']  ['python', 'ai solutions', 'ai frameworks', 'a...
# 3      ['data scientist']  ['python', 'neural networks', 'ai', 'numpy', '...
# 4      ['data scientist']  ['kubernetes', 'python', 'ai solutions', 'ai',...
# ...                   ...                                                ...
# 14420                  []  ['css', 'c++', 'web application', 'vue.js', 'c...
# 14421                  []  ['Unix', 'jQuery', 'Linux', 'Coding', 'Configu...
# 14422                  []  ['Automation', 'Backend', 'Front end', 'GIT', ...
# 14423                  []  ['css', 'code versioning tools', 'bootstrap', ...
# 14424                  []  ['rest', 'github', 'Postgresql', 'test driven ...
#
#         Posted_Date Last_Apply_Date                            Role  \
# 0        2 days ago     09 Sep 2025                 Data Engineer ,
# 1        2 days ago     25 Jul 2024                Data Scientist ,
# 2             Today     19 Aug 2025                Data Scientist ,
# 3        2 days ago     09 Nov 2024     Full Stack Data Scientist ,
# 4             Today     19 Aug 2025     Full Stack Data Scientist ,
# ...             ...             ...                             ...
# 14420  3+ weeks ago     15 Jun 2024           Front End Developer ,
# 14421  3+ weeks ago             NaN          Full Stack Developer ,
# 14422  3+ weeks ago     10 Jul 2025          Full Stack Developer ,
# 14423  3+ weeks ago             NaN  Software Development - Other ,
# 14424  3+ weeks ago             NaN            Back End Developer ,
#
#                        Industry Type                     Department  \
# 0                          Banking ,     Data Science & Analytics ,
# 1      Medical Services / Hospital ,     Data Science & Analytics ,
# 2         IT Services & Consulting ,     Data Science & Analytics ,
# 3                  Urban Transport ,     Data Science & Analytics ,
# 4         IT Services & Consulting ,     Data Science & Analytics ,
# ...                              ...                            ...
# 14420     IT Services & Consulting ,  Engineering - Software & QA ,
# 14421     IT Services & Consulting ,  Engineering - Software & QA ,
# 14422              Food Processing ,  Engineering - Software & QA ,
# 14423        Management Consulting ,  Engineering - Software & QA ,
# 14424     IT Services & Consulting ,  Engineering - Software & QA ,
#
#             Employment Type                    Role Category  \
# 0      Full Time, Permanent  Data Science & Machine Learning
# 1      Full Time, Permanent  Data Science & Machine Learning
# 2      Full Time, Permanent  Data Science & Machine Learning
# 3      Full Time, Permanent  Data Science & Machine Learning
# 4      Full Time, Permanent  Data Science & Machine Learning
# ...                     ...                              ...
# 14420  Full Time, Permanent             Software Development
# 14421  Full Time, Permanent             Software Development
# 14422  Full Time, Permanent             Software Development
# 14423  Full Time, Permanent             Software Development
# 14424  Full Time, Permanent             Software Development
#
#                                              Description  \
# 0      The Deutsche India is seeking a talented Data ...
# 1      Job Title Data Scientist Job Description Data ...
# 2      As an Associate Data Scientist at IBM, you wil...
# 3      Your future role Take on a new challenge and a...
# 4      Scale an existing RAG code base for a producti...
# ...                                                  ...
# 14420  Design, build and maintain efficient, reusable...
# 14421  We are looking for a Ruby developer responsibl...
# 14422  Helping customers to find products they need. ...
# 14423  As a backend developer, you will be responsibl...
# 14424  We are looking ROR developers to build systems...
#
#                                                  Job_URL  \
# 0      https://www.naukri.com/job-listings-data-scien...
# 1      https://www.naukri.com/job-listings-data-scien...
# 2      https://www.naukri.com/job-listings-data-scien...
# 3      https://www.naukri.com/job-listings-data-scien...
# 4      https://www.naukri.com/job-listings-data-scien...
# ...                                                  ...
# 14420  https://www.naukri.com/job-listings-ruby-on-ra...
# 14421  https://www.naukri.com/job-listings-ruby-on-ra...
# 14422  https://www.naukri.com/job-listings-ruby-on-ra...
# 14423  https://www.naukri.com/job-listings-ruby-on-ra...
# 14424  https://www.naukri.com/job-listings-ruby-on-ra...
#
#                        Scraped_At                 Job_Type
# 0      2025-12-03T21:54:40.504260           Data Scientist
# 1      2025-12-03T21:54:43.757232           Data Scientist
# 2      2025-12-03T21:54:47.228273           Data Scientist
# 3      2025-12-03T21:54:53.138785           Data Scientist
# 4      2025-12-03T21:54:59.775018           Data Scientist
# ...                           ...                      ...
# 14420  2025-12-29T09:28:59.405604  Ruby on Rails Developer
# 14421  2025-12-29T09:29:05.186656  Ruby on Rails Developer
# 14422  2025-12-29T09:29:11.179514  Ruby on Rails Developer
# 14423  2025-12-29T09:29:15.756483  Ruby on Rails Developer
# 14424  2025-12-29T09:29:19.288707  Ruby on Rails Developer
#
# [14425 rows x 19 columns]

# %%
df.loc[12259]
# Out:
# Title                                                    QA Engineer
# Company                                                Offchain Labs
# Experience                                               3 - 8 years
# Salary                                                 Not Disclosed
# Location                                                      Remote
# Education                EducationUG:Any GraduatePG:Any Postgraduate
# Star_Skills                                                       []
# Normal_Skills      ['Automation', 'Javascript', 'Performance test...
# Posted_Date                                            Few hours ago
# Last_Apply_Date                                                  NaN
# Role                         Blockchain Quality Assurance Engineer ,
# Industry Type                                   FinTech / Payments ,
# Department                             Engineering - Software & QA ,
# Employment Type                                 Full Time, Permanent
# Role Category                          Quality Assurance and Testing
# Description        At Offchain Labs, we aren t just building prod...
# Job_URL            https://www.naukri.com/job-listings-qa-enginee...
# Scraped_At                                2025-12-19T22:36:32.091659
# Job_Type                                                 QA Engineer
# Name: 12259, dtype: object

# %%
df["Title"][6534 ]
df["Title"][12259 ]
# df["Title"][14651   ]
# Out:
# 'QA Engineer'

# %%
df["Title"].sample(10)
# Out:
# 9450                    Associate_ Data Scientist (AI/ML)
# 3477                  Technical writer - Cisco Tech Comms
# 5064        Python Developer (Immediate joinee preferred)
# 7905                                   Back End Developer
# 5139                                       Java Developer
# 13387                        Data Engineer / Data Modeler
# 2400                              Ruby On Rails Developer
# 3778     Product Development Engineer  (Machine Learning)
# 13740                                Full Stack Developer
# 10888                            Custom Software Engineer
# Name: Title, dtype: object

# %% [markdown]
# #### Removing invalid entry

# %%
def remove_invalid_row(df: pd.DataFrame, features: list[str]) -> pd.DataFrame:
    """
    Remove invalid row from DataFrame by features.
    
    Args:
        df: Input DataFrame
        features: List of feature names to check for validity

    Returns:
        DataFrame with the specified row removed.

    """
    idx = set()
    for feature in features:
        for i, value in enumerate(df[feature]):
            if value is None:
                idx.add(i)

    return df.drop(index=idx)


df = remove_invalid_row(df, ["Title", "Company"])

# %% [markdown]
# #### Title Column Cleaning

# %%
unique_job_list = [
    "Data Scientist",
    "Machine Learning Engineer",
    "Data Analyst",
    "Business Analyst",
    "AI Engineer",
    "Research Associate",
    "Data Engineer",
    "Web Developer",
    "Software Engineer",
    "DevOps Engineer",
    "Product Manager",
    "Project Manager",
    "UX Designer",
    "Full Stack Developer",
    "Cloud Engineer",
    "DevOps Specialist",
    "Database Administrator",
    "Cybersecurity Analyst",
    "Network Engineer",
    "Systems Analyst",
    "IT Support Specialist",
    "Mobile App Developer",
    "Front End Developer",
    "Back End Developer",
    "QA Engineer",
    "Technical Writer",
    "Scrum Master",
    "Python Developer",
    "Java Developer",
    "Ruby on Rails Developer",
    "Big Data Engineer",
    "Data Architect",
    "AI Researcher",
    "Blockchain Developer",
    "Computer Vision Engineer",
    "NLP Engineer",
    "Robotics Engineer",
    "Game Developer",
    "Embedded Systems Engineer",
    "Site Reliability Engineer",
    "Solutions Architect",
    "IT Consultant",
    "Business Intelligence Analyst",
    "Generative AI Specialist",
    "Generative AI Engineer"
]

# %%
# fuzzy matching
from thefuzz import fuzz

# Returns an integer score out of 100
score = fuzz.ratio("Data Scientist", " Machine Learning Engineer and Data Scientist")
print(score) # Output: 90
score = fuzz.token_sort_ratio("Data Scientist", " Machine Learning Engineer and Data Scientist")
print(score) # Output: 90
score = fuzz.token_set_ratio("Data Scientist", " Machine Learning Engineer and Data Scientist")
print(score) # Output: 90

score = fuzz.ratio("Machine Learning Engineer", " Principal Engineer, Machine Learning")
print(score) # Output: 90

score = fuzz.ratio(" Frontend developer", "  Frontend developer - SE - Noida")
print(score) # Output: 90

score = fuzz.token_sort_ratio(" Frontend developer", "  Frontend developer - SE - Noida")
print(score) # Output: 90

score = fuzz.token_set_ratio(" Frontend developer", "  Frontend developer - SE - Noida")
print(score) # Output: 90
# Out:
# 47
# 48
# 100
# 52
# 73
# 80
# 100

# %%
def fuzzy_matcher(job_list , x):

    if x is None :
        return None
    
    if not job_list:
        raise ValueError("Please provide valid list of jobs")
    
    # changing case to lowercase and stripping leading/trailing spaces
    x = x.lower().strip()

    # removing metadata like ("Hiring", "Immediate Joiner", "Opening For", etc.)
    metadata_keywords = ["hiring", "immediate joiner", "opening for", "urgent hiring", "immediate joining"]
    for keyword in metadata_keywords:
        x = x.replace(keyword, "").strip()
    
    # removing location if any (e.g., "- Noida", "| Jaipur", etc.)
    x = re.split(r'[-|,|@]', x)[0].strip()

    # expafnding common abbreviations
    abbreviations = {
        "dev": "developer",
        "engg": "engineer",
        "mgr": "manager",
        "sr": "senior",
        "jr": "junior",
        "fs": "full stack",
        "ml": "machine learning",
        "ai": "artificial intelligence",
        "Gen Ai": "Generative Artificial Intelligence",
        "Gen Ai Developer": "Generative AI Engineer",
        "SRE": "Site Reliability Engineer"
    }
    for abbr, full_form in abbreviations.items():
        x = x.replace(abbr.lower(), full_form.lower()).strip()
    
    # removing seniority markers
    seniority_markers = ["senior", "jr.", "jr", "sr.", "lead", "principal", "associate", "intern", "trainee"]
    for marker in seniority_markers:
        x = x.replace(marker, "").strip()


    matching_score = {}

    for job in job_list:
        matching_score[f"{job}"] = fuzz.token_set_ratio(job, x)

    matched_job =[job for job, score in matching_score.items() if score >= 70]
    return matched_job

print(fuzzy_matcher(unique_job_list, "Machine Learning Engineer and Data Scientist"))
print(fuzzy_matcher(unique_job_list, "Frontend developer - SE - Noida"))
print(fuzzy_matcher(unique_job_list, "Gen Ai Developer"))
print(fuzzy_matcher(unique_job_list, "DevOps/SRE Lead (Specialist)-Pune"))
print(fuzzy_matcher(unique_job_list, "Gen AI/Agentic AI Engineers"))
print(fuzzy_matcher(unique_job_list, "Gen AI Engineer"))
print(fuzzy_matcher(unique_job_list, "Hiring Machine Learning Engineerr"))
print(fuzzy_matcher(unique_job_list, "Immediat Hiring for Machine Learning Engineerr"))
print(fuzzy_matcher(unique_job_list, "  Full stack Developer (React + Springboot)"))
print(fuzzy_matcher(unique_job_list, " Opening For Ruby on rails Developer"))
print(fuzzy_matcher(unique_job_list, " Hiring | Customer Service / Tech Support | Jaipur | 3 To 4 LPA"))
print(fuzzy_matcher(unique_job_list, " Hiring For International Voice Process - AR Callers"))
print(fuzzy_matcher(unique_job_list, " Python Software Developer- Bangalore (Pan India Infosys)"))
# Out:
# ['Data Scientist', 'Machine Learning Engineer', 'AI Engineer', 'Data Engineer', 'DevOps Engineer', 'Cloud Engineer', 'QA Engineer', 'Big Data Engineer', 'NLP Engineer']
# ['Front End Developer']
# []
# ['DevOps Specialist']
# []
# ['AI Engineer', 'Data Engineer', 'DevOps Engineer', 'Cloud Engineer', 'QA Engineer', 'NLP Engineer']
# ['Machine Learning Engineer']
# ['Machine Learning Engineer']
# []
# []
# []
# []
# []

# %%
# updated code 
import re
from fuzzywuzzy import fuzz

unique_job_list = [
    "Data Scientist",
    "Machine Learning Engineer",
    "Data Analyst",
    "Business Analyst",
    "AI Engineer",
    "Research Associate",
    "Data Engineer",
    "Web Developer",
    "Software Engineer",
    "DevOps Engineer",
    "Product Manager",
    "Project Manager",
    "UX Designer",
    "Full Stack Developer",
    "Cloud Engineer",
    "DevOps Specialist",
    "Database Administrator",
    "Cybersecurity Analyst",
    "Network Engineer",
    "Systems Analyst",
    "IT Support Specialist",
    "Mobile App Developer",
    "Front End Developer",
    "Back End Developer",
    "QA Engineer",
    "Technical Writer",
    "Scrum Master",
    "Python Developer",
    "Java Developer",
    "Ruby on Rails Developer",
    "Big Data Engineer",
    "Data Architect",
    "AI Researcher",
    "Blockchain Developer",
    "Computer Vision Engineer",
    "NLP Engineer",
    "Robotics Engineer",
    "Game Developer",
    "Embedded Systems Engineer",
    "Site Reliability Engineer",
    "Solutions Architect",
    "IT Consultant",
    "Business Intelligence Analyst",
    "Generative AI Specialist",
    "Generative AI Engineer",
    "Technical Support Specialist",
    "Customer Support Specialist"
]

def fuzzy_matcher(job_list, x):
    """
    Match job title to predefined job list using fuzzy matching.
    
    Args:
        job_list: List of standardized job titles
        x: Raw job title string to match
        
    Returns:
        List containing the best matching job title(s) or ["Other"] if no match
    """
    if x is None:
        return ["Other"]
    
    if not job_list:
        raise ValueError("Please provide valid list of jobs")
    
    # Convert to lowercase and strip whitespace
    x = x.lower().strip()
    
    # Remove metadata keywords using word boundaries
    metadata_patterns = [
        r'\bhiring\b', r'\bimmediate\s+joiner?\b', r'\bopening\s+for\b',
        r'\burgent\b', r'\bimmediate\s+joining\b', r'\bwalk-?in\b',
        r'\bfreshers?\b', r'\bexperienced?\b'
    ]
    for pattern in metadata_patterns:
        x = re.sub(pattern, '', x, flags=re.IGNORECASE).strip()
    
    # Remove location markers (before first separator)
    x = re.split(r'\s*[-|,@]\s*', x)[0].strip()
    
    # Expand abbreviations with word boundaries for precision
    # Order matters: longer patterns first to avoid partial replacements
    x = re.sub(r'\bgen\s*ai\b', 'generative ai', x, flags=re.IGNORECASE)
    x = re.sub(r'\bsre\b', 'site reliability engineer', x, flags=re.IGNORECASE)
    x = re.sub(r'\bml\b', 'machine learning', x, flags=re.IGNORECASE)
    x = re.sub(r'\bai\b', 'artificial intelligence', x, flags=re.IGNORECASE)
    x = re.sub(r'\bfs\b', 'full stack', x, flags=re.IGNORECASE)
    x = re.sub(r'\bdev\b', 'developer', x, flags=re.IGNORECASE)
    x = re.sub(r'\bengg?\b', 'engineer', x, flags=re.IGNORECASE)
    x = re.sub(r'\bmgr\b', 'manager', x, flags=re.IGNORECASE)
    
    # Remove seniority markers with word boundaries
    seniority_patterns = [
        r'\bsenior\b', r'\bjr\.?\b', r'\bsr\.?\b', r'\blead\b',
        r'\bprincipal\b', r'\bassociate\b', r'\bintern\b', r'\btrainee\b',
        r'\bmid-?level\b', r'\bentry-?level\b', r'\bstaff\b'
    ]
    for pattern in seniority_patterns:
        x = re.sub(pattern, '', x, flags=re.IGNORECASE).strip()
    
    # Remove extra whitespace
    x = re.sub(r'\s+', ' ', x).strip()
    
    # If empty after cleaning, return Other
    if not x:
        return ["Other"]
    
    # Calculate fuzzy match scores
    matching_scores = {}
    for job in job_list:
        matching_scores[job] = fuzz.token_set_ratio(job.lower(), x)
    
    # Sort by score descending
    sorted_matches = sorted(matching_scores.items(), key=lambda item: item[1], reverse=True)
    
    # Get top score
    top_score = sorted_matches[0][1]
    
    # Return matches based on score thresholds
    if top_score >= 80:
        # High confidence: return top match only
        return [sorted_matches[0][0]]
    elif top_score >= 70:
        # Medium confidence: return top 2 if second score is within 5 points
        top_matches = [sorted_matches[0][0]]
        if len(sorted_matches) > 1 and sorted_matches[1][1] >= top_score - 5:
            top_matches.append(sorted_matches[1][0])
        return top_matches
    else:
        # Low confidence: return "Other"
        return ["Other"]


# Test cases
print("1.", fuzzy_matcher(unique_job_list, "Machine Learning Engineer and Data Scientist"))
print("2.", fuzzy_matcher(unique_job_list, "Frontend developer - SE - Noida"))
print("3.", fuzzy_matcher(unique_job_list, "Gen Ai Developer"))
print("4.", fuzzy_matcher(unique_job_list, "DevOps/SRE Lead (Specialist)-Pune"))
print("5.", fuzzy_matcher(unique_job_list, "Gen AI/Agentic AI Engineers"))
print("6.", fuzzy_matcher(unique_job_list, "Gen AI Engineer"))
print("7.", fuzzy_matcher(unique_job_list, "Hiring Machine Learning Engineerr"))
print("8.", fuzzy_matcher(unique_job_list, "Immediat Hiring for Machine Learning Engineerr"))
print("9.", fuzzy_matcher(unique_job_list, "  Full stack Developer (React + Springboot)"))
print("10.", fuzzy_matcher(unique_job_list, " Opening For Ruby on rails Developer"))
print("11.", fuzzy_matcher(unique_job_list, " Hiring | Customer Service / Tech Support | Jaipur | 3 To 4 LPA"))
print("12.", fuzzy_matcher(unique_job_list, " Hiring For International Voice Process - AR Callers"))
print("13.", fuzzy_matcher(unique_job_list, " Python Software Developer- Bangalore (Pan India Infosys)"))
print("14.", fuzzy_matcher(unique_job_list, "Senior Software Engineer"))
print("15.", fuzzy_matcher(unique_job_list, "ML Engineer"))
print("16.", fuzzy_matcher(unique_job_list, "DevOps/Cloud Engineer"))
print("17.", fuzzy_matcher(unique_job_list, ""))
print("18.", fuzzy_matcher(unique_job_list, None))
# Out:
# 1. ['Data Scientist']
# 2. ['Web Developer']
# 3. ['Web Developer']
# 4. ['DevOps Engineer']
# 5. ['Other']
# 6. ['Generative AI Engineer']
# 7. ['Machine Learning Engineer']
# 8. ['Machine Learning Engineer']
# 9. ['Full Stack Developer']
# 10. ['Ruby on Rails Developer']
# 11. ['Other']
# 12. ['Other']
# 13. ['Python Developer']
# 14. ['Software Engineer']
# 15. ['Machine Learning Engineer']
# 16. ['DevOps Engineer']
# 17. ['Other']
# 18. ['Other']

# %%
df["TItle_Cleaned"] = df["Title"].apply(lambda x: fuzzy_matcher(unique_job_list, x))

# %% [markdown]
# #### Company Comumn Cleaning

# %%
df["Company"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14425 entries, 0 to 14424
# Series name: Company
# Non-Null Count  Dtype
# --------------  -----
# 14330 non-null  object
# dtypes: object(1)
# memory usage: 112.8+ KB

# %%
df["Company"].sample(10)
# Out:
# 1064                                       Accenture
# 4882    Prayatna-centre For Child Development-cochin
# 9205                           Posted by The Hr Bulb
# 1219                                           Wipro
# 4174                                       Accenture
# 199                                             Xoom
# 4911                                          Photon
# 9890                             Winjit Technologies
# 4430                       Posted by Intelex Systems
# 5269      Posted by Zorba Consulting India Pvt. Ltd.
# Name: Company, dtype: object

# %%
def remove_prefixes(string: str) -> str:
    """
    Remove specified prefixes from the string name.
    
    Args:
        string: The original string name.

    Returns:
        Cleaned string name without specified prefixes.
    """
    prefix_pattern = [
        r"\bHiring for \b",
        r"\bImmediate Hiring\b",
        r"\bPosted by\b",
        r"\bUrgent Hiring\b",
        r"\bWalk-in\b",
        r"\bOpening for\b",
        r"\bNow Hiring\b",
        r"Jobs at",
        r"Career at",
        r"\bHiring @ \b",
    ]
    if not isinstance(string, str) or string is None:
        return string

    for prefix in prefix_pattern:
        if re.match(prefix, string, re.IGNORECASE):
            string = re.sub(prefix, '', string, flags=re.IGNORECASE).strip()

    return string.lower()



def remove_suffixes(string: str) -> str:
    """
    Remove specified suffixes from the string name.
    
    Args:
        string: The original string name.

    Returns:
        Cleaned string name without specified suffixes.
    """
    if not isinstance(string, str) or string is None:
        return string

    suffix_pattern = [
        r"\b- Pvt Ltd\b",
        r"\b- Private Limited\b",
        r"\bLtd\b",
        r"\bLLP\b",
        r"\bInc\b",
        r"\bCorporation\b",
        r"\bCompany\b",
        r"\bCo\b",
    ]
    for suffix in suffix_pattern:
        if re.search(suffix, string, re.IGNORECASE):
            string = re.sub(suffix, '', string, flags=re.IGNORECASE).strip()
    return string.lower()

df["Company_Cleaned"] = df["Company"].apply(lambda x: remove_prefixes(x))
df["Company_Cleaned"] = df["Company_Cleaned"].apply(lambda x: remove_suffixes(x))

# %%
df["Company_Cleaned"].sample(10)
# Out:
# 5920                          adani group
# 2196                                  NaN
# 4495                     flexera software
# 680                               infosys
# 5975                     enterprise minds
# 10475                       allegis group
# 10820                           accenture
# 6969            accrete globus technology
# 7801                       apex invention
# 10146    ziniosedge software technologies
# Name: Company_Cleaned, dtype: object

# %%
# updated code 
import re
import pandas as pd

def clean_company_name(company: str) -> str:
    """
    Clean company name by removing hiring metadata, legal suffixes, and normalizing format.
    
    Args:
        company: Raw company name string
        
    Returns:
        Cleaned company name or "Unknown" if invalid/empty
    """
    # Handle None or non-string inputs
    if not isinstance(company, str) or company is None or pd.isna(company):
        return "Unknown"
    
    # Strip initial whitespace
    company = company.strip()
    
    if not company:
        return "Unknown"
    
    # Step 1: Remove hiring/job posting prefixes (case-insensitive)
    prefix_patterns = [
        r'\bHiring\s+for\b',
        r'\bImmediate\s+Hiring\b',
        r'\bPosted\s+by:?\b',
        r'\bUrgent\s+Hiring\b',
        r'\bWalk-?in\b',
        r'\bOpening\s+for\b',
        r'\bNow\s+Hiring\b',
        r'\bJobs?\s+at\b',
        r'\bCareers?\s+at\b',
        r'\bHiring\s*@\b',
        r'\bJoin\b',
        r'\bApply\s+to\b',
        r'\bWork\s+at\b'
    ]
    
    for pattern in prefix_patterns:
        company = re.sub(pattern, '', company, flags=re.IGNORECASE).strip()
    
    # Step 2: Split on common separators and take first part (main company name)
    # This handles cases like "Amazon | Bangalore" or "Google - Urgent"
    company = re.split(r'\s*[-|:@]\s*', company)[0].strip()
    
    # Step 3: Remove legal entity suffixes (case-insensitive)
    suffix_patterns = [
        r'\bPvt\.?\s*Ltd\.?\b',
        r'\bPrivate\s+Limited\b',
        r'\bLimited\b',
        r'\bLtd\.?\b',
        r'\bLLP\b',
        r'\bInc\.?\b',
        r'\bCorporation\b',
        r'\bCorp\.?\b',
        r'\bCompany\b',
        r'\bCo\.?\b(?!\w)',  # Only match "Co" if not part of another word
        r'\bPLC\b',
        r'\bLLC\b'
    ]
    
    for pattern in suffix_patterns:
        company = re.sub(pattern, '', company, flags=re.IGNORECASE).strip()
    
    # Step 4: Remove trailing urgency/metadata suffixes
    urgency_patterns = [
        r'\(?\s*Urgent\s*\)?',
        r'\(?\s*Immediate\s+Joiner\s*\)?',
        r'\(?\s*Work\s+From\s+Home\s*\)?',
        r'\(?\s*WFH\s*\)?',
        r'\(?\s*Remote\s*\)?',
        r'\(?\s*Hybrid\s*\)?'
    ]
    
    for pattern in urgency_patterns:
        company = re.sub(pattern, '', company, flags=re.IGNORECASE).strip()
    
    # Step 5: Normalize whitespace (multiple spaces → single space)
    company = re.sub(r'\s+', ' ', company).strip()
    
    # Step 6: Remove leading/trailing punctuation that might remain
    company = re.sub(r'^[,;:\-|@\s]+|[,;:\-|@\s]+$', '', company).strip()
    
    # Step 7: Handle empty results
    if not company or len(company) < 2:
        return "Unknown"
    
    # Step 8: Title case for consistency (optional - comment out if you want original case)
    # company = company.title()
    
    return company


# Test cases
test_cases = [
    "Hiring for Google Inc - Urgent",
    "Posted by: Amazon | Bangalore",
    "Accenture Pvt Ltd",
    "Microsoft Corporation",
    "Wipro",
    "TCS - Immediate Joiner",
    "Opening for Infosys Limited",
    "Now Hiring @ Adobe Inc.",
    "Flipkart - Work From Home",
    "Urgent Hiring - Cognizant",
    "Apple Inc - Remote",
    "  IBM Corp  ",
    "Oracle Corporation (Urgent)",
    "",
    None,
    "A",
    "Posted by Deloitte | Hyderabad | 5 LPA",
    "Cygnus Professionals",
    "Centre for Computational Technologies (CCTech)",
    "Mapmyindia Pvt. Ltd.",
    "Sirahu Technologies Inc"
]

print("Testing Company Name Cleaner:")
print("-" * 60)
for test in test_cases:
    result = clean_company_name(test)
    print(f"Input:  {repr(test):<45} → Output: {result}")

# Example usage with DataFrame
df["Company_Cleaned"] = df["Company"].apply(clean_company_name)
# Out:
# Testing Company Name Cleaner:
# ------------------------------------------------------------
# Input:  'Hiring for Google Inc - Urgent'              → Output: Google
# Input:  'Posted by: Amazon | Bangalore'               → Output: Unknown
# Input:  'Accenture Pvt Ltd'                           → Output: Accenture
# Input:  'Microsoft Corporation'                       → Output: Microsoft
# Input:  'Wipro'                                       → Output: Wipro
# Input:  'TCS - Immediate Joiner'                      → Output: TCS
# Input:  'Opening for Infosys Limited'                 → Output: Infosys
# Input:  'Now Hiring @ Adobe Inc.'                     → Output: Unknown
# Input:  'Flipkart - Work From Home'                   → Output: Flipkart
# Input:  'Urgent Hiring - Cognizant'                   → Output: Unknown
# Input:  'Apple Inc - Remote'                          → Output: Apple
# Input:  '  IBM Corp  '                                → Output: IBM
# Input:  'Oracle Corporation (Urgent)'                 → Output: Oracle
# Input:  ''                                            → Output: Unknown
# Input:  None                                          → Output: Unknown
# Input:  'A'                                           → Output: Unknown
# Input:  'Posted by Deloitte | Hyderabad | 5 LPA'      → Output: Deloitte
# Input:  'Cygnus Professionals'                        → Output: Cygnus Professionals
# Input:  'Centre for Computational Technologies (CCTech)' → Output: Centre for Computational Technologies (CCTech)
# Input:  'Mapmyindia Pvt. Ltd.'                        → Output: Mapmyindia .
# Input:  'Sirahu Technologies Inc'                     → Output: Sirahu Technologies

# %%
df["Company_Cleaned"].sample(10)
# Out:
# 3081                 Continuity 1
# 10402                     Artemyn
# 6934     Zorba Consulting India .
# 10595                      Artech
# 13961                         CGI
# 12429         Elvago Technologies
# 11264                WNS Holdings
# 9997                   Andor Tech
# 10065                 Globallogic
# 11162                     Unknown
# Name: Company_Cleaned, dtype: object

# %% [markdown]
# #### Cleaning Experience Column

# %%
unexpected_invalid_experience_values = [" No fixed duration", "No fixed duration", "Not fixed"]
df["Experience"].sample(10)

def extract_pxperence_range(value: str) -> str:
    """
    Extract experience range from the given value.
    
    Args:
        value: The original experience value.
    
    Returns:
        Extract minimum and maximum experience in tuple format

    """
    if not isinstance(value, str):
        return value
    
    # Regular expression to match experience range patterns
    pattern = r'(\d+\.?\d*)\s*-\s*(\d+\.?\d*)\s*years?|\b(\d+\.?\d*)\s*years?\b'
    match = re.search(pattern, value, re.IGNORECASE)
    
    if match:
        if match.group(1) and match.group(2):
            return (match.group(1), match.group(2))
        elif match.group(3):
            return (match.group(3), None)

    return (None, None)

def clean_experience(value: str, unexpected_values: list) -> str:
    """
    Clean the experience value by removing unexpected entries.
    
    Args:
        value: The original experience value.
        unexpected_values: List of unexpected values to remove.

    Returns:
        Cleaned experience value or None if it was unexpected.
    """
    if not isinstance(value, str):
        return value
    
    if value.strip() in unexpected_values:
        return (None, None)
    
    return value.strip()

df["Experience_Cleaned"] = df["Experience"].apply(lambda x: clean_experience(x, unexpected_invalid_experience_values))


df["Experience_Range"] = df["Experience"].apply(lambda x: extract_pxperence_range(x))
df["Experience_Range"].sample(10)
# Out:
# 6099     (1, 3)
# 8838     (1, 6)
# 13045    (3, 5)
# 3769     (3, 5)
# 10621    (3, 8)
# 3679     (1, 2)
# 8051     (1, 5)
# 885      (0, 1)
# 2024     (0, 3)
# 1021     (4, 9)
# Name: Experience_Range, dtype: object

# %%
# updated code
import re
import pandas as pd
import numpy as np

# Define unexpected/invalid values at module level
INVALID_EXPERIENCE_VALUES = [
    "No fixed duration",
    "Not fixed",
    "Not Mentioned",
    "NA",
    "N/A",
    "TBD",
    "To be decided",
    "Negotiable"
]

def extract_experience_range(value: str) -> tuple:
    """
    Extract experience range from the given value.
    
    Args:
        value: The original experience value string
    
    Returns:
        Tuple of (min_exp, max_exp) as floats, or (None, None) if invalid
        
    Examples:
        "3-5 years" → (3.0, 5.0)
        "5 years" → (5.0, 5.0)
        "5+ years" → (5.0, None)
        "Fresher" → (0.0, 0.0)
        "No fixed duration" → (None, None)
    """
    # Handle non-string inputs
    if not isinstance(value, str) or pd.isna(value):
        return (None, None)
    
    # Clean and normalize input
    value = value.strip()
    
    if not value:
        return (None, None)
    
    # Check if value is in invalid list
    if value in INVALID_EXPERIENCE_VALUES:
        return (None, None)
    
    # Pattern 1: Fresher / Entry Level / No Experience
    fresher_pattern = r'\b(fresher|entry[\s-]?level|no\s+experience|0\s*years?)\b'
    if re.search(fresher_pattern, value, re.IGNORECASE):
        return (0.0, 0.0)
    
    # Pattern 2: Range with hyphen or "to" (e.g., "3-5 years", "3 to 5 yrs")
    range_pattern = r'(\d+\.?\d*)\s*(?:-|to)\s*(\d+\.?\d*)\s*(?:years?|yrs?)\b'
    match = re.search(range_pattern, value, re.IGNORECASE)
    if match:
        min_exp = float(match.group(1))
        max_exp = float(match.group(2))
        
        # Validate and swap if needed
        if min_exp > max_exp:
            min_exp, max_exp = max_exp, min_exp
        
        return (min_exp, max_exp)
    
    # Pattern 3: Plus sign (e.g., "5+ years", "3+ yrs")
    plus_pattern = r'(\d+\.?\d*)\s*\+\s*(?:years?|yrs?)\b'
    match = re.search(plus_pattern, value, re.IGNORECASE)
    if match:
        exp = float(match.group(1))
        return (exp, None)  # Use None for open-ended upper bound
    
    # Pattern 4: Single value (e.g., "5 years", "3 yrs")
    single_pattern = r'\b(\d+\.?\d*)\s*(?:years?|yrs?)\b'
    match = re.search(single_pattern, value, re.IGNORECASE)
    if match:
        exp = float(match.group(1))
        return (exp, exp)  # Single value means exact match
    
    # Pattern 5: Just a number (e.g., "5", "3.5")
    number_pattern = r'\b(\d+\.?\d*)\b'
    match = re.search(number_pattern, value, re.IGNORECASE)
    if match:
        exp = float(match.group(1))
        return (exp, exp)
    
    # No match found
    return (None, None)


def get_experience_min(experience_tuple: tuple) -> float:
    """Extract minimum experience from tuple."""
    if experience_tuple and experience_tuple[0] is not None:
        return experience_tuple[0]
    return np.nan


def get_experience_max(experience_tuple: tuple) -> float:
    """Extract maximum experience from tuple."""
    if experience_tuple and experience_tuple[1] is not None:
        return experience_tuple[1]
    return np.nan


# Test cases
test_cases = [
    "3-5 years",
    "5 years",
    "5+ years",
    "Fresher",
    "Entry Level",
    "0 years",
    "3 to 5 years",
    "2-3 yrs",
    "10 Years+",
    "No experience",
    "No fixed duration",
    "Not fixed",
    "NA",
    "5",
    "3.5 years",
    "1.5-2.5 years",
    "10-5 years",  # Reversed - should swap
    "  7 years  ",
    "",
    None,
    "Not Mentioned",
    "0-1 years",
    "15+ yrs"
]

print("Testing Experience Range Extraction:")
print("-" * 80)
for test in test_cases:
    result = extract_experience_range(test)
    min_exp = result[0] if result[0] is not None else "None"
    max_exp = result[1] if result[1] is not None else "None"
    print(f"Input: {repr(test):<25} → Output: ({min_exp}, {max_exp})")

print("\n" + "=" * 80)
print("Example DataFrame Usage:")
print("=" * 80)

# Example with DataFrame
sample_data = {
    'Experience': [
        "3-5 years",
        "5 years",
        "5+ years",
        "Fresher",
        "No fixed duration",
        "3 to 5 yrs",
        "0-1 years"
    ]
}

df_example = pd.DataFrame(sample_data)

# Apply the function
df_example['Experience_Range'] = df_example['Experience'].apply(extract_experience_range)
df_example['Min_Experience'] = df_example['Experience_Range'].apply(get_experience_min)
df_example['Max_Experience'] = df_example['Experience_Range'].apply(get_experience_max)

print(df_example)

print("\n" + "=" * 80)
print("Usage with your actual DataFrame:")
print("=" * 80)
print("""
# Apply to your DataFrame:
df['Experience_Range'] = df['Experience'].apply(extract_experience_range)
df['Min_Experience'] = df['Experience_Range'].apply(get_experience_min)
df['Max_Experience'] = df['Experience_Range'].apply(get_experience_max)

# Optional: Filter valid experiences
df_valid = df[df['Min_Experience'].notna()]

# Optional: Filter by experience range
df_mid_level = df[(df['Min_Experience'] >= 3) & (df['Max_Experience'] <= 7)]
""")
# Out:
# Testing Experience Range Extraction:
# --------------------------------------------------------------------------------
# Input: '3-5 years'               → Output: (3.0, 5.0)
# Input: '5 years'                 → Output: (5.0, 5.0)
# Input: '5+ years'                → Output: (5.0, None)
# Input: 'Fresher'                 → Output: (0.0, 0.0)
# Input: 'Entry Level'             → Output: (0.0, 0.0)
# Input: '0 years'                 → Output: (0.0, 0.0)
# Input: '3 to 5 years'            → Output: (3.0, 5.0)
# Input: '2-3 yrs'                 → Output: (2.0, 3.0)
# Input: '10 Years+'               → Output: (10.0, 10.0)
# Input: 'No experience'           → Output: (0.0, 0.0)
# Input: 'No fixed duration'       → Output: (None, None)
# Input: 'Not fixed'               → Output: (None, None)
# Input: 'NA'                      → Output: (None, None)
# Input: '5'                       → Output: (5.0, 5.0)
# Input: '3.5 years'               → Output: (3.5, 3.5)
# Input: '1.5-2.5 years'           → Output: (1.5, 2.5)
# Input: '10-5 years'              → Output: (5.0, 10.0)
# Input: '  7 years  '             → Output: (7.0, 7.0)
# Input: ''                        → Output: (None, None)
# Input: None                      → Output: (None, None)
# Input: 'Not Mentioned'           → Output: (None, None)
# Input: '0-1 years'               → Output: (0.0, 1.0)
# Input: '15+ yrs'                 → Output: (15.0, None)
#
# ================================================================================
# Example DataFrame Usage:
# ================================================================================
#           Experience Experience_Range  Min_Experience  Max_Experience
# 0          3-5 years       (3.0, 5.0)             3.0             5.0
# 1            5 years       (5.0, 5.0)             5.0             5.0
# 2           5+ years      (5.0, None)             5.0             NaN
# 3            Fresher       (0.0, 0.0)             0.0             0.0
# 4  No fixed duration     (None, None)             NaN             NaN
# 5         3 to 5 yrs       (3.0, 5.0)             3.0             5.0
# 6          0-1 years       (0.0, 1.0)             0.0             1.0
#
# ================================================================================
# Usage with your actual DataFrame:
# ================================================================================
#
# # Apply to your DataFrame:
# df['Experience_Range'] = df['Experience'].apply(extract_experience_range)
# df['Min_Experience'] = df['Experience_Range'].apply(get_experience_min)
# df['Max_Experience'] = df['Experience_Range'].apply(get_experience_max)
#
# # Optional: Filter valid experiences
# df_valid = df[df['Min_Experience'].notna()]
#
# # Optional: Filter by experience range
# df_mid_level = df[(df['Min_Experience'] >= 3) & (df['Max_Experience'] <= 7)]

# %% [markdown]
# #### Cleaning Salary Column

# %%
df["Salary"].sample(10)
# Out:
# 2025       Not Disclosed
# 705        Not Disclosed
# 10367      Not Disclosed
# 5149       Not Disclosed
# 5905       Not Disclosed
# 7599       Not Disclosed
# 6772       Not Disclosed
# 1260       Not Disclosed
# 7963     15-30 Lacs P.A.
# 5361       Not Disclosed
# Name: Salary, dtype: object

# %%
def extract_salary_range(value: str) -> str:
    """
    Extract salary range from the given value.
    
    Args:
        value: The original salary value.
    
    Returns:
        Extracted salary range in tuple format (min_salary, max_salary)

    """
    if not isinstance(value, str):
        return value
    
    # Regular expression to match salary range patterns
    pattern = r'(\d+\.?\d*)\s*-\s*(\d+\.?\d*)\s|\b(\d+\.?\d*)\s*Lacs P.A\b'
    match = re.search(pattern, value, re.IGNORECASE)
    
    if match:
        if match.group(1) and match.group(2):
            return (match.group(1), match.group(2))
        elif match.group(3):
            return (match.group(3), None)

    return (None, None)

df["Salary_Range"] = df["Salary"].apply(lambda x: extract_salary_range(x))
df["Salary_Range"].sample(10)
# Out:
# 207            (2, 5)
# 169      (None, None)
# 13415    (None, None)
# 1761     (None, None)
# 3392     (None, None)
# 13339    (None, None)
# 4104     (None, None)
# 2537     (None, None)
# 14169    (None, None)
# 1876     (None, None)
# Name: Salary_Range, dtype: object

# %% [markdown]
# #### Cleaning Location Column

# %%
df["Location"].sample(10)
# Out:
# 11019          Mumbai,Navi Mumbai
# 2977                      Chennai
# 1158                    Bengaluru
# 11366                   New Delhi
# 3898     Hyderabad,Pune,Bengaluru
# 8730                    Bengaluru
# 13621                     Chennai
# 12862                   Bengaluru
# 10175                        Pune
# 13433                        Pune
# Name: Location, dtype: object

# %%
def clean_location(value: str):
    """
    Clean the location value by removing unwanted characters.
    
    Args:
        value: The original location value.

    Returns:
        Cleaned location value .
    """
    if not isinstance(value, str):
        return value

    cleaned = value.split(",")
    return cleaned

def isRemoteLocation(value: str):
    """
    Check if the location value indicates a remote location.
    
    Args:
        value: The original location value.
    Returns:
        True if remote location, False otherwise.
    """
    if not isinstance(value, str):
        return False

    remote_indicators = ["Remote", "Work from Home", "WFH", "Anywhere"]
    for indicator in remote_indicators:
        if indicator.lower() in value.lower():
            return True
    return False

df["Location_Cleaned"] = df["Location"].apply(lambda x: clean_location(x))
df["Location_Cleaned"].sample(10)

df["Is_Remote"] = df["Location"].apply(lambda x: isRemoteLocation(x))
df["Is_Remote"].sample(10)
# Out:
# 2153     False
# 4374     False
# 3612     False
# 10724    False
# 8871     False
# 8844     False
# 8977     False
# 5259     False
# 12085    False
# 12276    False
# Name: Is_Remote, dtype: bool

# %%
# updated Code
import re
import pandas as pd
import numpy as np

# Define invalid/undisclosed salary values
INVALID_SALARY_VALUES = [
    "Not Disclosed",
    "Salary Not Disclosed",
    "NA",
    "N/A",
    "Not Mentioned",
    "Negotiable",
    "Competitive",
    "As per industry standards",
    "TBD",
    "To be decided"
]

def extract_salary_range(value: str) -> tuple:
    """
    Extract salary range from the given value and normalize to Lakhs Per Annum (LPA).
    
    Args:
        value: The original salary value string
    
    Returns:
        Tuple of (min_salary, max_salary) as floats in LPA, or (None, None) if invalid
        
    Examples:
        "3-5 LPA" → (3.0, 5.0)
        "5 Lakhs" → (5.0, 5.0)
        "Upto 7 LPA" → (0.0, 7.0)
        "5+ LPA" → (5.0, None)
        "500000-700000" → (5.0, 7.0)  # Converted to Lakhs
        "Not Disclosed" → (None, None)
    """
    # Handle non-string inputs
    if not isinstance(value, str) or pd.isna(value):
        return (None, None)
    
    # Clean and normalize input
    value = value.strip()
    
    if not value:
        return (None, None)
    
    # Check if value is in invalid/undisclosed list (case-insensitive)
    if any(value.lower() == invalid.lower() for invalid in INVALID_SALARY_VALUES):
        return (None, None)
    
    # Pattern 1: "Upto X" or "Up to X" (e.g., "Upto 5 LPA", "Up to 7 Lakhs")
    upto_pattern = r'(?:upto|up\s*to)\s*(\d+\.?\d*)\s*(?:lpa|l\.?p\.?a\.?|lakhs?|lacs?|l)\b'
    match = re.search(upto_pattern, value, re.IGNORECASE)
    if match:
        max_salary = float(match.group(1))
        return (0.0, max_salary)
    
    # Pattern 2: "X+" (e.g., "5+ LPA", "3+ Lakhs")
    plus_pattern = r'(\d+\.?\d*)\s*\+\s*(?:lpa|l\.?p\.?a\.?|lakhs?|lacs?|l)\b'
    match = re.search(plus_pattern, value, re.IGNORECASE)
    if match:
        min_salary = float(match.group(1))
        return (min_salary, None)
    
    # Pattern 3: Range with LPA/Lakhs/Lacs units (e.g., "3-5 LPA", "3 to 5 Lakhs")
    range_with_unit_pattern = r'(\d+\.?\d*)\s*(?:-|to)\s*(\d+\.?\d*)\s*(?:lpa|l\.?p\.?a\.?|lakhs?|lacs?|l)(?:\s*p\.?a\.?|\s*per\s*annum)?\b'
    match = re.search(range_with_unit_pattern, value, re.IGNORECASE)
    if match:
        min_salary = float(match.group(1))
        max_salary = float(match.group(2))
        
        # Validate and swap if needed
        if min_salary > max_salary:
            min_salary, max_salary = max_salary, min_salary
        
        return (min_salary, max_salary)
    
    # Pattern 4: Single value with LPA/Lakhs/Lacs (e.g., "5 LPA", "3.5 Lakhs")
    single_with_unit_pattern = r'(\d+\.?\d*)\s*(?:lpa|l\.?p\.?a\.?|lakhs?|lacs?|l)(?:\s*p\.?a\.?|\s*per\s*annum)?\b'
    match = re.search(single_with_unit_pattern, value, re.IGNORECASE)
    if match:
        salary = float(match.group(1))
        return (salary, salary)
    
    # Pattern 5: Absolute numbers range (e.g., "500000-700000", "50000 to 70000")
    # Convert to Lakhs (divide by 100,000)
    absolute_range_pattern = r'(\d{5,})\s*(?:-|to)\s*(\d{5,})'
    match = re.search(absolute_range_pattern, value, re.IGNORECASE)
    if match:
        min_salary = float(match.group(1)) / 100000  # Convert to Lakhs
        max_salary = float(match.group(2)) / 100000
        
        # Validate and swap if needed
        if min_salary > max_salary:
            min_salary, max_salary = max_salary, min_salary
        
        # Round to 2 decimal places
        return (round(min_salary, 2), round(max_salary, 2))
    
    # Pattern 6: Single absolute number (e.g., "600000", "500000")
    # Convert to Lakhs if >= 10000 (assume it's in rupees, not lakhs)
    absolute_single_pattern = r'(\d{5,})'
    match = re.search(absolute_single_pattern, value, re.IGNORECASE)
    if match:
        salary = float(match.group(1)) / 100000  # Convert to Lakhs
        salary = round(salary, 2)
        return (salary, salary)
    
    # Pattern 7: Just numbers with range (fallback, e.g., "3-5", "5 to 7")
    # Assume already in Lakhs if no unit specified and numbers are small
    simple_range_pattern = r'(\d+\.?\d*)\s*(?:-|to)\s*(\d+\.?\d*)'
    match = re.search(simple_range_pattern, value, re.IGNORECASE)
    if match:
        min_salary = float(match.group(1))
        max_salary = float(match.group(2))
        
        # Only accept if numbers are reasonable for Lakhs (< 100)
        if min_salary < 100 and max_salary < 100:
            if min_salary > max_salary:
                min_salary, max_salary = max_salary, min_salary
            return (min_salary, max_salary)
    
    # No match found
    return (None, None)


def get_salary_min(salary_tuple: tuple) -> float:
    """Extract minimum salary from tuple."""
    if salary_tuple and salary_tuple[0] is not None:
        return salary_tuple[0]
    return np.nan


def get_salary_max(salary_tuple: tuple) -> float:
    """Extract maximum salary from tuple."""
    if salary_tuple and salary_tuple[1] is not None:
        return salary_tuple[1]
    return np.nan


def get_salary_avg(salary_tuple: tuple) -> float:
    """Calculate average salary from tuple."""
    if salary_tuple and salary_tuple[0] is not None and salary_tuple[1] is not None:
        return round((salary_tuple[0] + salary_tuple[1]) / 2, 2)
    elif salary_tuple and salary_tuple[0] is not None:
        return salary_tuple[0]
    return np.nan


# Test cases
test_cases = [
    "3-5 LPA",
    "5-7 Lakhs PA",
    "3.5 Lacs",
    "Upto 5 LPA",
    "5+ LPA",
    "Not Disclosed",
    "500000-700000",
    "600000",
    "3 to 5 LPA",
    "5 L",
    "3-5 L.P.A",
    "7 Lakhs Per Annum",
    "Negotiable",
    "NA",
    "3.5-5.5 Lakhs",
    "Up to 10 LPA",
    "8+ Lakhs",
    "300000",
    "10-5 LPA",  # Reversed - should swap
    "  5 LPA  ",
    "",
    None,
    "As per industry standards",
    "1000000-1500000",  # 10-15 Lakhs
    "2.5 to 4 L"
]

print("Testing Salary Range Extraction:")
print("-" * 80)
for test in test_cases:
    result = extract_salary_range(test)
    min_sal = result[0] if result[0] is not None else "None"
    max_sal = result[1] if result[1] is not None else "None"
    print(f"Input: {repr(test):<35} → Output: ({min_sal}, {max_sal})")

print("\n" + "=" * 80)
print("Example DataFrame Usage:")
print("=" * 80)

# Example with DataFrame
sample_data = {
    'Salary': [
        "3-5 LPA",
        "5 Lakhs",
        "Upto 7 LPA",
        "5+ LPA",
        "Not Disclosed",
        "500000-700000",
        "3 to 5 Lakhs"
    ]
}

df_example = pd.DataFrame(sample_data)

# Apply the function
df_example['Salary_Range'] = df_example['Salary'].apply(extract_salary_range)
df_example['Min_Salary'] = df_example['Salary_Range'].apply(get_salary_min)
df_example['Max_Salary'] = df_example['Salary_Range'].apply(get_salary_max)
df_example['Avg_Salary'] = df_example['Salary_Range'].apply(get_salary_avg)

print(df_example)

print("\n" + "=" * 80)
print("Usage with your actual DataFrame:")
print("=" * 80)
print("""
# Apply to your DataFrame:
df['Salary_Range'] = df['Salary'].apply(extract_salary_range)
df['Min_Salary'] = df['Salary_Range'].apply(get_salary_min)
df['Max_Salary'] = df['Salary_Range'].apply(get_salary_max)
df['Avg_Salary'] = df['Salary_Range'].apply(get_salary_avg)

# Optional: Filter valid salaries
df_valid = df[df['Min_Salary'].notna()]

# Optional: Filter by salary range
df_mid_range = df[(df['Min_Salary'] >= 3) & (df['Max_Salary'] <= 10)]

# Optional: Find jobs with competitive pay (> 5 LPA average)
df_high_pay = df[df['Avg_Salary'] > 5]
""")
# Out:
# Testing Salary Range Extraction:
# --------------------------------------------------------------------------------
# Input: '3-5 LPA'                           → Output: (3.0, 5.0)
# Input: '5-7 Lakhs PA'                      → Output: (5.0, 7.0)
# Input: '3.5 Lacs'                          → Output: (3.5, 3.5)
# Input: 'Upto 5 LPA'                        → Output: (0.0, 5.0)
# Input: '5+ LPA'                            → Output: (5.0, None)
# Input: 'Not Disclosed'                     → Output: (None, None)
# Input: '500000-700000'                     → Output: (5.0, 7.0)
# Input: '600000'                            → Output: (6.0, 6.0)
# Input: '3 to 5 LPA'                        → Output: (3.0, 5.0)
# Input: '5 L'                               → Output: (5.0, 5.0)
# Input: '3-5 L.P.A'                         → Output: (3.0, 5.0)
# Input: '7 Lakhs Per Annum'                 → Output: (7.0, 7.0)
# Input: 'Negotiable'                        → Output: (None, None)
# Input: 'NA'                                → Output: (None, None)
# Input: '3.5-5.5 Lakhs'                     → Output: (3.5, 5.5)
# Input: 'Up to 10 LPA'                      → Output: (0.0, 10.0)
# Input: '8+ Lakhs'                          → Output: (8.0, None)
# Input: '300000'                            → Output: (3.0, 3.0)
# Input: '10-5 LPA'                          → Output: (5.0, 10.0)
# Input: '  5 LPA  '                         → Output: (5.0, 5.0)
# Input: ''                                  → Output: (None, None)
# Input: None                                → Output: (None, None)
# Input: 'As per industry standards'         → Output: (None, None)
# Input: '1000000-1500000'                   → Output: (10.0, 15.0)
# Input: '2.5 to 4 L'                        → Output: (2.5, 4.0)
#
# ================================================================================
# Example DataFrame Usage:
# ================================================================================
#           Salary  Salary_Range  Min_Salary  Max_Salary  Avg_Salary
# 0        3-5 LPA    (3.0, 5.0)         3.0         5.0         4.0
# 1        5 Lakhs    (5.0, 5.0)         5.0         5.0         5.0
# 2     Upto 7 LPA    (0.0, 7.0)         0.0         7.0         3.5
# 3         5+ LPA   (5.0, None)         5.0         NaN         5.0
# 4  Not Disclosed  (None, None)         NaN         NaN         NaN
# 5  500000-700000    (5.0, 7.0)         5.0         7.0         6.0
# 6   3 to 5 Lakhs    (3.0, 5.0)         3.0         5.0         4.0
#
# ================================================================================
# Usage with your actual DataFrame:
# ================================================================================
#
# # Apply to your DataFrame:
# df['Salary_Range'] = df['Salary'].apply(extract_salary_range)
# df['Min_Salary'] = df['Salary_Range'].apply(get_salary_min)
# df['Max_Salary'] = df['Salary_Range'].apply(get_salary_max)
# df['Avg_Salary'] = df['Salary_Range'].apply(get_salary_avg)
#
# # Optional: Filter valid salaries
# df_valid = df[df['Min_Salary'].notna()]
#
# # Optional: Filter by salary range
# df_mid_range = df[(df['Min_Salary'] >= 3) & (df['Max_Salary'] <= 10)]
#
# # Optional: Find jobs with competitive pay (> 5 LPA average)
# df_high_pay = df[df['Avg_Salary'] > 5]

# %% [markdown]
# #### Education column cleaning

# %%
df["Education"].sample(30)
# Out:
# 5855     EducationUG:B.Tech/B.E. in Any SpecializationP...
# 5380           EducationUG:Any GraduatePG:Any Postgraduate
# 7136     EducationUG:B.Tech/B.E. in Any SpecializationP...
# 13986                  EducationUG:Any GraduatePG:CA in CA
# 12932                             EducationUG:Any Graduate
# 11208                             EducationUG:Any Graduate
# 7388           EducationUG:Any GraduatePG:Any Postgraduate
# 5640     EducationUG:B.Tech/B.E. in Production/Industri...
# 5254     EducationUG:B.Tech/B.E. in Production/Industri...
# 6557           EducationUG:Any GraduatePG:Any Postgraduate
# 6457           EducationUG:Any GraduatePG:Any Postgraduate
# 4742           EducationUG:Any GraduatePG:Any Postgraduate
# 2988                              EducationUG:Any Graduate
# 9806     EducationUG:B.Tech/B.E. in Any SpecializationP...
# 11522    EducationUG:B.Tech/B.E. in Any SpecializationP...
# 10253          EducationUG:Any GraduatePG:Any Postgraduate
# 11577        EducationUG:B.Tech/B.E. in Any Specialization
# 4257     EducationUG:B.Tech/B.E. in Any SpecializationP...
# 13003    EducationUG:B.Tech/B.E. in Computer Science En...
# 12245    EducationUG:B.Com in Commerce, Any Graduate, B...
# 3871           EducationUG:Any GraduatePG:Any Postgraduate
# 8843           EducationUG:Any GraduatePG:Any Postgraduate
# 11563    EducationUG:B.Tech/B.E. in Any SpecializationP...
# 7656     EducationUG:Any GraduatePG:Post Graduation Not...
# 6480                   EducationUG:Graduation Not Required
# 7244     EducationUG:B.Tech/B.E. in Any SpecializationP...
# 4237     EducationUG:B.Tech/B.E. in Any SpecializationP...
# 9412           EducationUG:Any GraduatePG:Any Postgraduate
# 598      EducationUG:B.Tech/B.E. in Any SpecializationP...
# 6960           EducationUG:Any GraduatePG:Any Postgraduate
# Name: Education, dtype: object

# %%
# text = df["Education"].sample(1).to_string()

# pattern = r'(UG|PG):(.*?)(?=UG|PG|$)'

# matches = re.findall(pattern, text)

# # Convert to dictionary
# edu_dict = {key: value.strip() for key, value in matches}

# print(edu_dict)


def clean_education(value: str) -> dict:
    """
    Clean the education value by extracting UG and PG details.
    
    Args:
        value: The original education value.
    Returns:
        Dictionary with UG and PG details.
    """
    if not isinstance(value, str):
        return value
    pattern = r'(UG|PG):(.*?)(?=UG|PG|$)'
    matches = re.findall(pattern, value)
    edu_dict = {key: value.strip() for key, value in matches}
    return edu_dict

df["Education_Cleaned"] = df["Education"].apply(lambda x: clean_education(x))
df["Education_Cleaned"].sample(10)
# Out:
# 9067     {'UG': 'B.Tech/B.E. in Any Specialization', 'P...
# 1782     {'UG': 'B.Tech/B.E. in Any Specialization', 'P...
# 595      {'UG': 'Any Graduate, B.Tech/B.E. in Any Speci...
# 13386                               {'UG': 'Any Graduate'}
# 11192    {'UG': 'Any Graduate', 'PG': 'Any Postgraduate...
# 12754                               {'UG': 'Any Graduate'}
# 9633      {'UG': 'Any Graduate', 'PG': 'Any Postgraduate'}
# 13317    {'UG': 'Any Graduate, B.A', 'PG': 'Any Postgra...
# 7705      {'UG': 'Any Graduate', 'PG': 'Any Postgraduate'}
# 14373                               {'UG': 'Any Graduate'}
# Name: Education_Cleaned, dtype: object

# %%
import re
import pandas as pd
import numpy as np

def clean_education(value: str) -> dict:
    """
    Clean education value by extracting and normalizing UG and PG details.
    
    Args:
        value: Original education string (e.g., "UG: B.Tech/B.E. in Computer Science, PG: M.Tech in AI")
    
    Returns:
        Dictionary with keys: UG_Degree, UG_Specialization, PG_Degree, PG_Specialization
        
    Examples:
        "UG: B.Tech/B.E. in Computer Science" 
        → {"UG_Degree": "B.Tech", "UG_Specialization": "Computer Science", 
           "PG_Degree": None, "PG_Specialization": None}
    """
    # Default structure
    result = {
        "UG_Degree": None,
        "UG_Specialization": None,
        "PG_Degree": None,
        "PG_Specialization": None
    }
    
    # Handle invalid inputs
    if not isinstance(value, str) or pd.isna(value) or not value.strip():
        return result
    
    value = value.strip()
    
    # Check for "Not Required" patterns
    if re.search(r'\b(not required|not specified|any|na|n/a)\b', value, re.IGNORECASE):
        if "UG" in value:
            result["UG_Degree"] = "Not Required"
        if "PG" in value:
            result["PG_Degree"] = "Not Required"
        return result
    
    # Extract UG and PG sections
    pattern = r'(UG|PG):\s*(.*?)(?=\s*(?:UG|PG):|$)'
    matches = re.findall(pattern, value, re.IGNORECASE)
    
    for level, content in matches:
        level = level.upper()
        content = content.strip().rstrip(',').strip()
        
        if not content:
            continue
        
        # Check for "Any Graduate" pattern
        if re.search(r'\bany\s+(graduate|postgraduate)\b', content, re.IGNORECASE):
            if level == "UG":
                result["UG_Degree"] = "Any Graduate"
            else:
                result["PG_Degree"] = "Any Postgraduate"
            continue
        
        # Extract degree and specialization
        # Pattern: "B.Tech/B.E. in Computer Science" or "M.Tech in AI"
        degree_spec_pattern = r'([A-Za-z./]+(?:\s*\/\s*[A-Za-z./]+)*)\s+in\s+(.+)'
        match = re.search(degree_spec_pattern, content, re.IGNORECASE)
        
        if match:
            degree = match.group(1).strip()
            specialization = match.group(2).strip()
            
            # Normalize degree
            degree = normalize_degree(degree)
            
            if level == "UG":
                result["UG_Degree"] = degree
                result["UG_Specialization"] = specialization
            else:
                result["PG_Degree"] = degree
                result["PG_Specialization"] = specialization
        else:
            # No "in" keyword - treat entire content as degree
            degree = normalize_degree(content)
            
            if level == "UG":
                result["UG_Degree"] = degree
                result["UG_Specialization"] = "Any Specialization"
            else:
                result["PG_Degree"] = degree
                result["PG_Specialization"] = "Any Specialization"
    
    return result


def normalize_degree(degree: str) -> str:
    """
    Normalize degree names to standard format.
    
    Examples:
        "B.Tech/B.E." → "B.Tech"
        "Bachelor of Technology" → "B.Tech"
        "M.Tech" → "M.Tech"
    """
    degree = degree.strip()
    
    # Common degree mappings
    degree_map = {
        # Undergraduate
        r'\b(b\.?tech|b\.?e\.?|bachelor\s+of\s+technology|bachelor\s+of\s+engineering)\b': 'B.Tech',
        r'\b(bca|bachelor\s+of\s+computer\s+applications?)\b': 'BCA',
        r'\b(bsc|b\.?sc\.?|bachelor\s+of\s+science)\b': 'B.Sc',
        r'\b(bcom|b\.?com\.?|bachelor\s+of\s+commerce)\b': 'B.Com',
        r'\b(ba|b\.?a\.?|bachelor\s+of\s+arts)\b': 'B.A',
        r'\b(bba|bachelor\s+of\s+business\s+administration)\b': 'BBA',
        r'\b(diploma)\b': 'Diploma',
        
        # Postgraduate
        r'\b(m\.?tech|m\.?e\.?|master\s+of\s+technology|master\s+of\s+engineering)\b': 'M.Tech',
        r'\b(mca|master\s+of\s+computer\s+applications?)\b': 'MCA',
        r'\b(msc|m\.?sc\.?|master\s+of\s+science)\b': 'M.Sc',
        r'\b(mba|master\s+of\s+business\s+administration)\b': 'MBA',
        r'\b(ma|m\.?a\.?|master\s+of\s+arts)\b': 'M.A',
        r'\b(phd|ph\.?d\.?|doctorate)\b': 'Ph.D',
        r'\b(mcom|m\.?com\.?|master\s+of\s+commerce)\b': 'M.Com',
    }
    
    for pattern, normalized in degree_map.items():
        if re.search(pattern, degree, re.IGNORECASE):
            return normalized
    
    # If no match, return cleaned version
    return degree.replace('/', ' ').strip()


# Test cases
test_cases = [
    "UG: B.Tech/B.E. in Computer Science, PG: M.Tech in Artificial Intelligence",
    "UG: Any Graduate, PG: Any Postgraduate",
    "UG: B.Tech/B.E. in Mechanical",
    "UG: BCA in Computer Applications",
    "UG: B.Sc in Physics, PG: M.Sc in Data Science",
    "UG: Bachelor of Technology in ECE",
    "UG: Not Required, PG: MBA",
    "UG: Diploma in Engineering",
    "PG: Ph.D in Machine Learning",
    "",
    None,
    "UG: B.Tech/B.E. in Any Specialization, PG: M.Tech in VLSI",
    "UG: Any Graduate",
    "UG: BBA, PG: MBA in Finance"
]

print("Testing Education Cleaning:")
print("-" * 100)
for test in test_cases:
    result = clean_education(test)
    print(f"Input: {repr(test):<70}")
    print(f"  UG: {result['UG_Degree']} | {result['UG_Specialization']}")
    print(f"  PG: {result['PG_Degree']} | {result['PG_Specialization']}")
    print()

print("=" * 100)
print("Example DataFrame Usage:")
print("=" * 100)

# Example with DataFrame
sample_data = {
    'Education': [
        "UG: B.Tech/B.E. in Computer Science, PG: M.Tech in AI",
        "UG: Any Graduate, PG: Any Postgraduate",
        "UG: BCA in Computer Applications",
        "UG: Not Required, PG: MBA",
        None
    ]
}

df_example = pd.DataFrame(sample_data)

# Apply the function
df_example['Education_Cleaned'] = df_example['Education'].apply(clean_education)

# Extract into separate columns
df_example['UG_Degree'] = df_example['Education_Cleaned'].apply(lambda x: x['UG_Degree'])
df_example['UG_Specialization'] = df_example['Education_Cleaned'].apply(lambda x: x['UG_Specialization'])
df_example['PG_Degree'] = df_example['Education_Cleaned'].apply(lambda x: x['PG_Degree'])
df_example['PG_Specialization'] = df_example['Education_Cleaned'].apply(lambda x: x['PG_Specialization'])

print(df_example[['Education', 'UG_Degree', 'UG_Specialization', 'PG_Degree', 'PG_Specialization']])

print("\n" + "=" * 100)
print("Recommended Usage:")
print("=" * 100)
print("""
# Apply cleaning
df['Education_Cleaned'] = df['Education'].apply(clean_education)

# Extract to separate columns for easy filtering
df['UG_Degree'] = df['Education_Cleaned'].apply(lambda x: x['UG_Degree'])
df['UG_Specialization'] = df['Education_Cleaned'].apply(lambda x: x['UG_Specialization'])
df['PG_Degree'] = df['Education_Cleaned'].apply(lambda x: x['PG_Degree'])
df['PG_Specialization'] = df['Education_Cleaned'].apply(lambda x: x['PG_Specialization'])

# Example queries:
# Find all B.Tech Computer Science jobs
df_cs_jobs = df[df['UG_Specialization'].str.contains('Computer', na=False)]

# Find jobs requiring PG degree
df_pg_required = df[df['PG_Degree'].notna() & (df['PG_Degree'] != 'Not Required')]

# Count by degree type
df['UG_Degree'].value_counts()
""")
# Out:
# Testing Education Cleaning:
# ----------------------------------------------------------------------------------------------------
# Input: 'UG: B.Tech/B.E. in Computer Science, PG: M.Tech in Artificial Intelligence'
#   UG: B.Tech | Computer Science
#   PG: M.Tech | Artificial Intelligence
#
# Input: 'UG: Any Graduate, PG: Any Postgraduate'
#   UG: Not Required | None
#   PG: Not Required | None
#
# Input: 'UG: B.Tech/B.E. in Mechanical'
#   UG: B.Tech | Mechanical
#   PG: None | None
#
# Input: 'UG: BCA in Computer Applications'
#   UG: BCA | Computer Applications
#   PG: None | None
#
# Input: 'UG: B.Sc in Physics, PG: M.Sc in Data Science'
#   UG: B.Sc | Physics
#   PG: M.Sc | Data Science
#
# Input: 'UG: Bachelor of Technology in ECE'
#   UG: Technology | ECE
#   PG: None | None
#
# Input: 'UG: Not Required, PG: MBA'
#   UG: Not Required | None
#   PG: Not Required | None
#
# Input: 'UG: Diploma in Engineering'
#   UG: Diploma | Engineering
#   PG: None | None
#
# Input: 'PG: Ph.D in Machine Learning'
#   UG: None | None
#   PG: Ph.D | Machine Learning
#
# Input: ''
#   UG: None | None
#   PG: None | None
#
# Input: None
#   UG: None | None
#   PG: None | None
#
# Input: 'UG: B.Tech/B.E. in Any Specialization, PG: M.Tech in VLSI'
#   UG: Not Required | None
#   PG: Not Required | None
#
# Input: 'UG: Any Graduate'
#   UG: Not Required | None
#   PG: None | None
#
# Input: 'UG: BBA, PG: MBA in Finance'
#   UG: BBA | Any Specialization
#   PG: MBA | Finance
#
# ====================================================================================================
# Example DataFrame Usage:
# ====================================================================================================
#                                            Education     UG_Degree  \
# 0  UG: B.Tech/B.E. in Computer Science, PG: M.Tec...        B.Tech
# 1             UG: Any Graduate, PG: Any Postgraduate  Not Required
# 2                   UG: BCA in Computer Applications           BCA
# 3                          UG: Not Required, PG: MBA  Not Required
# 4                                               None          None
#
#        UG_Specialization     PG_Degree PG_Specialization
# 0       Computer Science        M.Tech                AI
# 1                   None  Not Required              None
# 2  Computer Applications          None              None
# 3                   None  Not Required              None
# 4                   None          None              None
#
# ====================================================================================================
# Recommended Usage:
# ====================================================================================================
#
# # Apply cleaning
# df['Education_Cleaned'] = df['Education'].apply(clean_education)
#
# # Extract to separate columns for easy filtering
# df['UG_Degree'] = df['Education_Cleaned'].apply(lambda x: x['UG_Degree'])
# df['UG_Specialization'] = df['Education_Cleaned'].apply(lambda x: x['UG_Specialization'])
# df['PG_Degree'] = df['Education_Cleaned'].apply(lambda x: x['PG_Degree'])
# df['PG_Specialization'] = df['Education_Cleaned'].apply(lambda x: x['PG_Specialization'])
#
# # Example queries:
# # Find all B.Tech Computer Science jobs
# df_cs_jobs = df[df['UG_Specialization'].str.contains('Computer', na=False)]
#
# # Find jobs requiring PG degree
# df_pg_required = df[df['PG_Degree'].notna() & (df['PG_Degree'] != 'Not Required')]
#
# # Count by degree type
# df['UG_Degree'].value_counts()

# %% [markdown]
# #### Cleaning Skill Column

# %%
df["Star_Skills"].sample(10)
# Out:
# 5412     ['python', 'Data engineer', 'pyspark', 'AWS', ...
# 2747                                 ['software engineer']
# 12048                    ['travel and expense management']
# 2020                                                    []
# 6864                                    ['data scientist']
# 1660          ['Ux Design', 'Figma', 'Wireframe', 'Adobe']
# 10917                                ['software engineer']
# 2833                                ['Product Management']
# 3220     ['Migration', 'Data Analysis', 'Agile', 'Scrum...
# 12121                          ['Flutter', 'React Native']
# Name: Star_Skills, dtype: object

# %%
type(df["Star_Skills"][0])
# Out:
# str

# %%
df["Normal_Skills"].sample(10)
# Out:
# 55       ['Tensorflow', 'Pytorch', 'Ml Deployment', 'Py...
# 3810      ['Data Analytics', 'Machine Learning', 'Python']
# 5033                                     ['Agile Process']
# 6719     ['', 'innovation', 'time management', 'multita...
# 33       ['Computer science', 'Career development', 'da...
# 12997                        ['PMP', 'Program Management']
# 3807     ['matlab', 's3', 'python', 'data analysis', 's...
# 11258    ['Power BI', 'Data Visualization', 'Data Analy...
# 647      ['restful', 'sql', 'microservices', 'docker', ...
# 13644    ['cloud', 'Agile', 'Project Delivery', 'Scrum'...
# Name: Normal_Skills, dtype: object

# %%
def getCombinedSkills(star_skills: str, normal_skills: str) -> list:
    """
    Combine star skills and normal skills into a single list.
    
    Args:
        star_skills: Comma-separated string of star skills.
        normal_skills: Comma-separated string of normal skills.
    Returns:
        List of combined skills. 

    """
    combined_skills = set()

    if isinstance(star_skills, str) and star_skills.strip():
        star_skills_list = star_skills.strip("[]").split(",")
        star_skills_list = [skill for skill in star_skills_list if skill is not None and skill.strip() and skill not in [",", "[]"]]
        combined_skills.update(star_skills_list)
    
    if isinstance(normal_skills, str) and normal_skills.strip():
        normal_skills_list = normal_skills.strip("[]").split(",")
        normal_skills_list = [skill for skill in normal_skills_list if skill is not None and skill.strip() and skill not in [",", "[]"]]
        combined_skills.update(normal_skills_list)
    
    return list(combined_skills)

print(getCombinedSkills(df["Star_Skills"][2], df["Normal_Skills"].iloc[2]))
# Out:
# [" 'matplotlib'", "'data scientist'", " 'java'", " 'tensorflow'", " 'cloud'", " 'big data'", " 'keras'", " 'pandas'", "'python'", " 'ai frameworks'", " 'technical documentation'", " 'agile'", " 'programming'", " 'cloud platforms'", " 'ai solutions'", " 'machine learning'", " 'artificial intelligence'", " 'pytorch'", " 'ai'", " 'open source'", " 'r'"]

# %%
df["Star_Skills"].sample()
# Out:
# 9170    ['Team Handling', 'Profitability', 'Cost Effic...
# Name: Star_Skills, dtype: object

# %%
df["Star_Skills"].iloc[3467].strip("[]").split(",")
# Out:
# ['']

# %%
# updated code:
import re
import pandas as pd
from typing import Union, List

# Skill normalization mapping (abbreviations and synonyms)
SKILL_NORMALIZATION = {
    # Programming Languages
    'js': 'JavaScript',
    'javascript': 'JavaScript',
    'reactjs': 'React',
    'react.js': 'React',
    'nodejs': 'Node.js',
    'node.js': 'Node.js',
    'node': 'Node.js',
    'ts': 'TypeScript',
    'typescript': 'TypeScript',
    'py': 'Python',
    'python': 'Python',
    'c++': 'C++',
    'cpp': 'C++',
    'c#': 'C#',
    'csharp': 'C#',
    'golang': 'Go',
    
    # Frameworks & Libraries
    'angular.js': 'Angular',
    'angularjs': 'Angular',
    'vue.js': 'Vue',
    'vuejs': 'Vue',
    'nextjs': 'Next.js',
    'next.js': 'Next.js',
    'expressjs': 'Express.js',
    'express.js': 'Express.js',
    'django': 'Django',
    'flask': 'Flask',
    'springboot': 'Spring Boot',
    'spring boot': 'Spring Boot',
    
    # Data Science & ML
    'ml': 'Machine Learning',
    'machine learning': 'Machine Learning',
    'ai': 'Artificial Intelligence',
    'artificial intelligence': 'Artificial Intelligence',
    'dl': 'Deep Learning',
    'deep learning': 'Deep Learning',
    'nlp': 'Natural Language Processing',
    'cv': 'Computer Vision',
    'computer vision': 'Computer Vision',
    'tensorflow': 'TensorFlow',
    'pytorch': 'PyTorch',
    'scikit-learn': 'Scikit-learn',
    'sklearn': 'Scikit-learn',
    'pandas': 'Pandas',
    'numpy': 'NumPy',
    
    # Databases
    'sql': 'SQL',
    'mysql': 'MySQL',
    'postgresql': 'PostgreSQL',
    'postgres': 'PostgreSQL',
    'mongodb': 'MongoDB',
    'mongo': 'MongoDB',
    'nosql': 'NoSQL',
    'redis': 'Redis',
    
    # Cloud & DevOps
    'aws': 'AWS',
    'amazon web services': 'AWS',
    'azure': 'Azure',
    'gcp': 'Google Cloud Platform',
    'google cloud': 'Google Cloud Platform',
    'docker': 'Docker',
    'kubernetes': 'Kubernetes',
    'k8s': 'Kubernetes',
    'ci/cd': 'CI/CD',
    'jenkins': 'Jenkins',
    'git': 'Git',
    'github': 'GitHub',
    'gitlab': 'GitLab',
    
    # Other
    'api': 'API',
    'rest api': 'REST API',
    'restful': 'REST API',
    'graphql': 'GraphQL',
    'html': 'HTML',
    'css': 'CSS',
    'sass': 'SASS',
    'scss': 'SCSS',
}

# Skills to exclude (noise/invalid)
INVALID_SKILLS = {
    'etc', 'and', 'or', 'with', 'using', 'knowledge', 'experience',
    'skills', 'good', 'strong', 'excellent', 'basic', 'advanced',
    'familiarity', 'understanding', 'ability', 'na', 'n/a', 'none',
    'required', 'preferred', 'must', 'have', 'plus', 'bonus'
}


def normalize_skill(skill: str) -> Union[str, None]:
    """
    Normalize a single skill name.
    
    Args:
        skill: Raw skill string
        
    Returns:
        Normalized skill name or None if invalid
    """
    if not skill or not isinstance(skill, str):
        return None
    
    # Clean whitespace and convert to lowercase for matching
    skill = skill.strip().lower()
    
    # Remove common punctuation at edges
    skill = re.sub(r'^[.,;:\-/|()]+|[.,;:\-/|()]+$', '', skill).strip()
    
    # Skip if empty after cleaning
    if not skill or len(skill) < 2:
        return None
    
    # Skip if in invalid list
    if skill in INVALID_SKILLS:
        return None
    
    # Skip single letters (unless known abbreviations like 'R', 'C')
    if len(skill) == 1 and skill not in ['r', 'c']:
        return None
    
    # Normalize using mapping
    if skill in SKILL_NORMALIZATION:
        return SKILL_NORMALIZATION[skill]
    
    # Return title-cased version if not in mapping
    return skill.title()


def parse_skills_string(skills_str: Union[str, List]) -> List[str]:
    """
    Parse skills from string or list format.
    
    Args:
        skills_str: Skills as string (comma/pipe/semicolon separated) or list
        
    Returns:
        List of individual skill strings
    """
    # Handle None or empty
    if pd.isna(skills_str) or not skills_str:
        return []
    
    # If already a list
    if isinstance(skills_str, list):
        return [str(s).strip() for s in skills_str if s]
    
    # Convert to string if not already
    skills_str = str(skills_str).strip()
    
    # Remove surrounding brackets if present (e.g., "[Python, SQL]")
    skills_str = re.sub(r'^\[|\]$', '', skills_str)
    
    # Remove quotes that might wrap skills
    skills_str = re.sub(r'["\']', '', skills_str)
    
    # Split on multiple possible separators: comma, pipe, semicolon, forward slash
    skills_list = re.split(r'[,|;/]', skills_str)
    
    # Clean each skill
    skills_list = [s.strip() for s in skills_list if s and s.strip()]
    
    return skills_list


def get_combined_skills(star_skills: Union[str, List], 
                        normal_skills: Union[str, List],
                        preserve_order: bool = True) -> List[str]:
    """
    Combine and normalize star skills and normal skills.
    
    Args:
        star_skills: Primary/featured skills (string or list)
        normal_skills: Additional skills (string or list)
        preserve_order: If True, star skills appear first (default: True)
        
    Returns:
        List of unique, normalized skills
        
    Examples:
        star_skills = "Python, ML, JS"
        normal_skills = "SQL, python, machine learning"
        → ["Python", "Machine Learning", "JavaScript", "SQL"]
    """
    # Parse skills from both sources
    star_list = parse_skills_string(star_skills)
    normal_list = parse_skills_string(normal_skills)
    
    # Normalize all skills
    normalized_star = [normalize_skill(s) for s in star_list]
    normalized_normal = [normalize_skill(s) for s in normal_list]
    
    # Remove None values
    normalized_star = [s for s in normalized_star if s is not None]
    normalized_normal = [s for s in normalized_normal if s is not None]
    
    if preserve_order:
        # Keep star skills first, then add normal skills not already present
        # Use dict to maintain order while deduplicating (Python 3.7+)
        seen = {}
        for skill in normalized_star:
            seen[skill] = None
        for skill in normalized_normal:
            if skill not in seen:
                seen[skill] = None
        return list(seen.keys())
    else:
        # Just deduplicate without preserving order
        return list(set(normalized_star + normalized_normal))


def get_skill_count(skills_list: List[str]) -> int:
    """Get count of skills in list."""
    return len(skills_list) if isinstance(skills_list, list) else 0


def has_skill(skills_list: List[str], target_skill: str) -> bool:
    """Check if target skill is in the skills list (case-insensitive)."""
    if not isinstance(skills_list, list):
        return False
    target_normalized = normalize_skill(target_skill)
    return target_normalized in skills_list if target_normalized else False


# Test cases
test_cases = [
    # (star_skills, normal_skills)
    ("Python, ML, JS", "SQL, python, machine learning"),
    ("[React, Node.js]", "JavaScript, reactjs, nodejs"),
    ("AWS, Docker, K8s", "Kubernetes, aws, docker, CI/CD"),
    ("", "Python, Java, C++"),
    (None, "Machine Learning, Deep Learning"),
    ("Python", None),
    ("Python, etc, and, SQL", "good knowledge of ML"),
    ("TensorFlow, PyTorch", "tensorflow, pytorch, pandas"),
    ("HTML/CSS/JavaScript", "React|Angular|Vue"),
    ("'Python', 'SQL'", "['AWS', 'Docker']"),
]

print("Testing Skills Cleaning:")
print("-" * 100)
for star, normal in test_cases:
    result = get_combined_skills(star, normal)
    print(f"Star:   {repr(star):<40}")
    print(f"Normal: {repr(normal):<40}")
    print(f"Result: {result}")
    print(f"Count:  {len(result)} skills")
    print()

print("=" * 100)
print("Example DataFrame Usage:")
print("=" * 100)

# Example with DataFrame
sample_data = {
    'Star_Skills': [
        "Python, ML, JS",
        "[React, Node.js]",
        "AWS, Docker, K8s",
        None,
        "TensorFlow, PyTorch"
    ],
    'Normal_Skills': [
        "SQL, python, machine learning",
        "JavaScript, reactjs, nodejs",
        "Kubernetes, aws, docker, CI/CD",
        "Python, Java, C++",
        "tensorflow, pytorch, pandas"
    ]
}

df_example = pd.DataFrame(sample_data)

# Apply cleaning
df_example['Combined_Skills'] = df_example.apply(
    lambda row: get_combined_skills(row['Star_Skills'], row['Normal_Skills']), 
    axis=1
)

df_example['Skill_Count'] = df_example['Combined_Skills'].apply(get_skill_count)

# Check for specific skills
df_example['Has_Python'] = df_example['Combined_Skills'].apply(lambda x: has_skill(x, 'Python'))
df_example['Has_ML'] = df_example['Combined_Skills'].apply(lambda x: has_skill(x, 'Machine Learning'))

print(df_example[['Star_Skills', 'Normal_Skills', 'Combined_Skills', 'Skill_Count']])

print("\n" + "=" * 100)
print("Recommended Usage:")
print("=" * 100)
print("""
# Apply skills cleaning
df['Combined_Skills'] = df.apply(
    lambda row: get_combined_skills(row['Star_Skills'], row['Normal_Skills']),
    axis=1
)

df['Skill_Count'] = df['Combined_Skills'].apply(get_skill_count)

# Find jobs requiring specific skills
df['Requires_Python'] = df['Combined_Skills'].apply(lambda x: has_skill(x, 'Python'))
df['Requires_ML'] = df['Combined_Skills'].apply(lambda x: 'Machine Learning' in x if isinstance(x, list) else False)

# Filter jobs by skills
python_jobs = df[df['Requires_Python']]
ml_jobs = df[df['Requires_ML']]

# Most common skills (flatten all skill lists)
from collections import Counter
all_skills = [skill for skills in df['Combined_Skills'] for skill in skills]
skill_frequency = Counter(all_skills)
print(skill_frequency.most_common(20))

# Skills co-occurrence analysis
# Find what skills appear together with Python
python_jobs_skills = df[df['Requires_Python']]['Combined_Skills']
python_cooccurrence = Counter([s for skills in python_jobs_skills for s in skills if s != 'Python'])
""")
# Out:
# Testing Skills Cleaning:
# ----------------------------------------------------------------------------------------------------
# Star:   'Python, ML, JS'
# Normal: 'SQL, python, machine learning'
# Result: ['Python', 'Machine Learning', 'JavaScript', 'SQL']
# Count:  4 skills
#
# Star:   '[React, Node.js]'
# Normal: 'JavaScript, reactjs, nodejs'
# Result: ['React', 'Node.js', 'JavaScript']
# Count:  3 skills
#
# Star:   'AWS, Docker, K8s'
# Normal: 'Kubernetes, aws, docker, CI/CD'
# Result: ['AWS', 'Docker', 'Kubernetes', 'Ci', 'Cd']
# Count:  5 skills
#
# Star:   ''
# Normal: 'Python, Java, C++'
# Result: ['Python', 'Java', 'C++']
# Count:  3 skills
#
# Star:   None
# Normal: 'Machine Learning, Deep Learning'
# Result: ['Machine Learning', 'Deep Learning']
# Count:  2 skills
#
# Star:   'Python'
# Normal: None
# Result: ['Python']
# Count:  1 skills
#
# Star:   'Python, etc, and, SQL'
# Normal: 'good knowledge of ML'
# Result: ['Python', 'SQL', 'Good Knowledge Of Ml']
# Count:  3 skills
#
# Star:   'TensorFlow, PyTorch'
# Normal: 'tensorflow, pytorch, pandas'
# Result: ['TensorFlow', 'PyTorch', 'Pandas']
# Count:  3 skills
#
# Star:   'HTML/CSS/JavaScript'
# Normal: 'React|Angular|Vue'
# Result: ['HTML', 'CSS', 'JavaScript', 'React', 'Angular', 'Vue']
# Count:  6 skills
#
# Star:   "'Python', 'SQL'"
# Normal: "['AWS', 'Docker']"
# Result: ['Python', 'SQL', 'AWS', 'Docker']
# Count:  4 skills
#
# ====================================================================================================
# Example DataFrame Usage:
# ====================================================================================================
#            Star_Skills                   Normal_Skills  \
# 0       Python, ML, JS   SQL, python, machine learning
# 1     [React, Node.js]     JavaScript, reactjs, nodejs
# 2     AWS, Docker, K8s  Kubernetes, aws, docker, CI/CD
# 3                 None               Python, Java, C++
# 4  TensorFlow, PyTorch     tensorflow, pytorch, pandas
#
#                                Combined_Skills  Skill_Count
# 0  [Python, Machine Learning, JavaScript, SQL]            4
# 1                 [React, Node.js, JavaScript]            3
# 2            [AWS, Docker, Kubernetes, Ci, Cd]            5
# 3                          [Python, Java, C++]            3
# 4                [TensorFlow, PyTorch, Pandas]            3
#
# ====================================================================================================
# Recommended Usage:
# ====================================================================================================
#
# # Apply skills cleaning
# df['Combined_Skills'] = df.apply(
#     lambda row: get_combined_skills(row['Star_Skills'], row['Normal_Skills']),
#     axis=1
# )
#
# df['Skill_Count'] = df['Combined_Skills'].apply(get_skill_count)
#
# # Find jobs requiring specific skills
# df['Requires_Python'] = df['Combined_Skills'].apply(lambda x: has_skill(x, 'Python'))
# df['Requires_ML'] = df['Combined_Skills'].apply(lambda x: 'Machine Learning' in x if isinstance(x, list) else False)
#
# # Filter jobs by skills
# python_jobs = df[df['Requires_Python']]
# ml_jobs = df[df['Requires_ML']]
#
# # Most common skills (flatten all skill lists)
# from collections import Counter
# all_skills = [skill for skills in df['Combined_Skills'] for skill in skills]
# skill_frequency = Counter(all_skills)
# print(skill_frequency.most_common(20))
#
# # Skills co-occurrence analysis
# # Find what skills appear together with Python
# python_jobs_skills = df[df['Requires_Python']]['Combined_Skills']
# python_cooccurrence = Counter([s for skills in python_jobs_skills for s in skills if s != 'Python'])

# %% [markdown]
# #### Industry Type feature cleaning

# %%
df["Industry Type"].head()
# Out:
# 0                        Banking ,
# 1    Medical Services / Hospital ,
# 2       IT Services & Consulting ,
# 3                Urban Transport ,
# 4       IT Services & Consulting ,
# Name: Industry Type, dtype: object

# %%
for industry in df["Industry Type"]:

    industry = industry.replace("/", ",").strip()
    # print(industry)

    print(industry.split(","), len(industry.split(",")))
# Out:
# ['Banking ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Urban Transport ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Agriculture ', ' Forestry ', ' Fishing ', ''] 4
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['Automobile ', ''] 2
# ['Power ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Retail ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Oil & Gas ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Advertising & Marketing ', ''] 2
# ['Miscellaneous ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Legal ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['Consumer Electronics & Appliances ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['Software Product ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Building Material ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['Legal ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['Financial Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['Engineering & Construction ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Fertilizers ', ' Pesticides ', ' Agro chemicals ', ''] 4
# ['Power (Solar) ', ''] 2
# ['Film ', ' Music ', ' Entertainment ', ''] 4
# ['Medical Devices & Equipment ', ''] 2
# ['Accounting ', ' Auditing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['Chemicals (Paints) ', ''] 2
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['Gems & Jewellery ', ''] 2
# ['Insurance ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Railways ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Advertising & Marketing ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Biotechnology ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Film ', ' Music ', ' Entertainment ', ''] 4
# ['Management Consulting ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Urban Transport ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['Defence & Aerospace ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Beverage ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['Miscellaneous ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Power ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Power ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Engineering & Construction ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['Travel & Tourism ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Consumer Electronics & Appliances ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Hardware & Networking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Consumer Electronics & Appliances ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['Industrial Automation ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['Software Product ', ''] 2
# ['Legal ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Travel & Tourism ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Retail ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Insurance ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Engineering & Construction ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['Fertilizers ', ' Pesticides ', ' Agro chemicals ', ''] 4
# ['Medical Services ', ' Hospital ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Telecom ', ' ISP ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Retail ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['Medical Services ', ' Hospital (Diagnostics) ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Travel & Tourism ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['Aviation ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Advertising & Marketing (Digital Marketing) ', ''] 2
# ['Automobile ', ''] 2
# ['Telecom ', ' ISP ', ''] 3
# ['Retail ', ''] 2
# ['Retail ', ''] 2
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['Investment Banking ', ' Venture Capital ', ' Private Equity ', ''] 4
# ['Retail ', ''] 2
# ['Film ', ' Music ', ' Entertainment ', ''] 4
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Water Treatment ', ' Waste Management ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Automobile (Electric Vehicle (EV)) ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Financial Services ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['NGO ', ' Social Services ', ' Industry Associations ', ''] 4
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Financial Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['FMCG ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['Financial Services ', ''] 2
# ['NGO ', ' Social Services ', ' Industry Associations ', ''] 4
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Biotechnology ', ''] 2
# ['Biotechnology ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Management Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['NGO ', ' Social Services ', ' Industry Associations ', ''] 4
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['Management Consulting ', ''] 2
# ['Banking ', ''] 2
# ['NGO ', ' Social Services ', ' Industry Associations ', ''] 4
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Education ', ' Training ', ''] 3
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Chemicals ', ''] 2
# ['Oil & Gas ', ''] 2
# ['Management Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Management Consulting ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Education ', ' Training ', ''] 3
# ['Software Product ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Automobile (Automobile Dealers) ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Hardware & Networking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Accounting ', ' Auditing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['TV ', ' Radio ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Textile & Apparel (Fashion) ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Investment Banking ', ' Venture Capital ', ' Private Equity ', ''] 4
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Real Estate ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['NBFC ', ''] 2
# ['Insurance ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['Engineering & Construction ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Aviation ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['Medical Devices & Equipment ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Miscellaneous ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['Financial Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['Miscellaneous ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Courier ', ' Logistics (Logistics Tech) ', ''] 3
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Investment Banking ', ' Venture Capital ', ' Private Equity ', ''] 4
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Automobile ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Internet ', ''] 2
# ['Software Product ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['E-Learning ', ' EdTech ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Advertising & Marketing ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['E-Learning ', ' EdTech ', ''] 3
# ['E-Learning ', ' EdTech ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['Management Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Retail ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Medical Services ', ' Hospital (Diagnostics) ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Automobile ', ''] 2
# ['Retail ', ''] 2
# ['Management Consulting ', ''] 2
# ['Retail ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Investment Banking ', ' Venture Capital ', ' Private Equity ', ''] 4
# ['Financial Services (Broking) ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['Banking ', ''] 2
# ['Banking ', ''] 2
# ['Automobile (Electric Vehicle (EV)) ', ''] 2
# ['Software Product ', ''] 2
# ['Travel & Tourism ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['TV ', ' Radio ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Water Treatment ', ' Waste Management ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['FMCG ', ''] 2
# ['Financial Services ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Education ', ' Training ', ''] 3
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Biotechnology ', ''] 2
# ['Biotechnology ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['NGO ', ' Social Services ', ' Industry Associations ', ''] 4
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['IT Services & Consulting ', ''] 2
# ['Investment Banking ', ' Venture Capital ', ' Private Equity ', ''] 4
# ['Management Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['Management Consulting ', ''] 2
# ['Oil & Gas ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Management Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Software Product ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Law Enforcement ', ' Security Services ', ''] 3
# ['Chemicals ', ''] 2
# ['NGO ', ' Social Services ', ' Industry Associations ', ''] 4
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Education ', ' Training ', ''] 3
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Recruitment ', ' Staffing ', ''] 3
# ['Biotechnology ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Management Consulting ', ''] 2
# ['NGO ', ' Social Services ', ' Industry Associations ', ''] 4
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Pharmaceutical & Life Sciences ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Urban Transport ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Real Estate ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Hardware & Networking ', ''] 2
# ['Insurance ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Insurance ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Accounting ', ' Auditing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Advertising & Marketing ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Real Estate ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['TV ', ' Radio ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['TV ', ' Radio ', ''] 3
# ['Advertising & Marketing (Digital Marketing) ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Real Estate ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Real Estate ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Hardware & Networking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Insurance ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['TV ', ' Radio ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['BPM ', ' BPO ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Advertising & Marketing (Digital Marketing) ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Real Estate ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Printing & Publishing ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['TV ', ' Radio ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Advertising & Marketing ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Real Estate ', ''] 2
# ['Real Estate ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Automobile (Automobile Dealers) ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Automobile (Electric Vehicle (EV)) ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Real Estate ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Hardware & Networking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Insurance ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['Printing & Publishing ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Accounting ', ' Auditing ', ''] 3
# ['TV ', ' Radio ', ''] 3
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Real Estate ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['Real Estate ', ''] 2
# ['Financial Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ...
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['Real Estate (Co-working) ', ''] 2
# ['Management Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['BPM ', ' BPO ', ''] 3
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Telecom ', ' ISP ', ''] 3
# ['BPM ', ' BPO ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Water Treatment ', ' Waste Management ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['BPM ', ' BPO ', ''] 3
# ['BPM ', ' BPO ', ''] 3
# ['Advertising & Marketing (Digital Marketing) ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['BPM ', ' BPO ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Insurance ', ''] 2
# ['Banking ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['Textile & Apparel ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['Food Processing ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Engineering & Construction ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['BPM ', ' BPO ', ''] 3
# ['BPM ', ' BPO ', ''] 3
# ['Engineering & Construction ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Petrochemical ', ' Plastics ', ' Rubber ', ''] 4
# ['FMCG ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Building Material ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Petrochemical ', ' Plastics ', ' Rubber ', ''] 4
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Film ', ' Music ', ' Entertainment ', ''] 4
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Retail ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet (E-Commerce) ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['Advertising & Marketing ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['Advertising & Marketing ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Engineering & Construction ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Insurance ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Medical Services ', ' Hospital ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Fitness & Wellness ', ''] 2
# ['Gaming ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Import & Export ', ''] 2
# ['Medical Services ', ' Hospital ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['Internet ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Advertising & Marketing ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Industrial Automation ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Miscellaneous ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Industrial Automation ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Insurance ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['Software Product ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['FinTech ', ' Payments ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['Industrial Equipment ', ' Machinery ', ''] 3
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Engineering & Construction ', ''] 2
# ['Oil & Gas ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['Retail ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Engineering & Construction ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Printing & Publishing ', ''] 2
# ['Facility Management Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Electronic Components ', ' Semiconductors ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['Financial Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Defence & Aerospace ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Courier ', ' Logistics ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Financial Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['BPM ', ' BPO ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Biotechnology ', ''] 2
# ['Biotechnology ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Banking ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Consumer Electronics & Appliances ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Emerging Technologies (IoT) ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Management Consulting ', ''] 2
# ['Architecture ', ' Interior Design ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['FinTech ', ' Payments ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['Facility Management Services ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Education ', ' Training ', ''] 3
# ['Analytics ', ' KPO ', ' Research ', ''] 4
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Software Product ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Internet ', ''] 2
# ['Internet ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['Education ', ' Training ', ''] 3
# ['E-Learning ', ' EdTech ', ''] 3
# ['E-Learning ', ' EdTech ', ''] 3
# ['E-Learning ', ' EdTech ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['E-Learning ', ' EdTech ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Recruitment ', ' Staffing ', ''] 3
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Automobile ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2
# ['Food Processing ', ''] 2
# ['Management Consulting ', ''] 2
# ['IT Services & Consulting ', ''] 2

# %%
for industry in df["Industry Type"]:
    # 1. Replace the separator
    # 2. strip(" ,/") removes spaces, commas, AND slashes from the ends
    clean_industry = industry.replace("/", ",").strip(" ,/")
    
    parts = clean_industry.split(",")
    
    # Optional: Clean up whitespace inside the list items too
    parts = [p.strip() for p in parts if p.strip()]
    
    print(parts, len(parts))
# Out:
# ['Banking'] 1
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['Urban Transport'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Agriculture', 'Forestry', 'Fishing'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Automobile'] 1
# ['Power'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Retail'] 1
# ['IT Services & Consulting'] 1
# ['Oil & Gas'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['FinTech', 'Payments'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Electronic Components', 'Semiconductors'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Advertising & Marketing'] 1
# ['Miscellaneous'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['Legal'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['FinTech', 'Payments'] 2
# ['Consumer Electronics & Appliances'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['Software Product'] 1
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Building Material'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['Legal'] 1
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['Industrial Equipment', 'Machinery'] 2
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['Engineering & Construction'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Fertilizers', 'Pesticides', 'Agro chemicals'] 3
# ['Power (Solar)'] 1
# ['Film', 'Music', 'Entertainment'] 3
# ['Medical Devices & Equipment'] 1
# ['Accounting', 'Auditing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Medical Services', 'Hospital'] 2
# ['Chemicals (Paints)'] 1
# ['Industrial Equipment', 'Machinery'] 2
# ['Gems & Jewellery'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Railways'] 1
# ['IT Services & Consulting'] 1
# ['Advertising & Marketing'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['Biotechnology'] 1
# ['IT Services & Consulting'] 1
# ['Film', 'Music', 'Entertainment'] 3
# ['Management Consulting'] 1
# ['Medical Services', 'Hospital'] 2
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Urban Transport'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['Defence & Aerospace'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Beverage'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Miscellaneous'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['Power'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Power'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Engineering & Construction'] 1
# ['IT Services & Consulting'] 1
# ['Electronic Components', 'Semiconductors'] 2
# ['Travel & Tourism'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Consumer Electronics & Appliances'] 1
# ['IT Services & Consulting'] 1
# ['Hardware & Networking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Consumer Electronics & Appliances'] 1
# ['Education', 'Training'] 2
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['Electronic Components', 'Semiconductors'] 2
# ['Industrial Automation'] 1
# ['IT Services & Consulting'] 1
# ['FinTech', 'Payments'] 2
# ['Software Product'] 1
# ['Legal'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Travel & Tourism'] 1
# ['IT Services & Consulting'] 1
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Retail'] 1
# ['IT Services & Consulting'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['Engineering & Construction'] 1
# ['FinTech', 'Payments'] 2
# ['Industrial Equipment', 'Machinery'] 2
# ['Fertilizers', 'Pesticides', 'Agro chemicals'] 3
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['Telecom', 'ISP'] 2
# ['Education', 'Training'] 2
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['Retail'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Recruitment', 'Staffing'] 2
# ['Medical Services', 'Hospital (Diagnostics)'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Travel & Tourism'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['Aviation'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Education', 'Training'] 2
# ['Advertising & Marketing (Digital Marketing)'] 1
# ['Automobile'] 1
# ['Telecom', 'ISP'] 2
# ['Retail'] 1
# ['Retail'] 1
# ['Electronic Components', 'Semiconductors'] 2
# ['Investment Banking', 'Venture Capital', 'Private Equity'] 3
# ['Retail'] 1
# ['Film', 'Music', 'Entertainment'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Water Treatment', 'Waste Management'] 2
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Automobile (Electric Vehicle (EV))'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Electronic Components', 'Semiconductors'] 2
# ['Electronic Components', 'Semiconductors'] 2
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Financial Services'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['NGO', 'Social Services', 'Industry Associations'] 3
# ['Analytics', 'KPO', 'Research'] 3
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['FMCG'] 1
# ['Education', 'Training'] 2
# ['Education', 'Training'] 2
# ['Education', 'Training'] 2
# ['Education', 'Training'] 2
# ['Financial Services'] 1
# ['NGO', 'Social Services', 'Industry Associations'] 3
# ['Analytics', 'KPO', 'Research'] 3
# ['Biotechnology'] 1
# ['Biotechnology'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['Management Consulting'] 1
# ['Management Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['NGO', 'Social Services', 'Industry Associations'] 3
# ['Pharmaceutical & Life Sciences'] 1
# ['Medical Services', 'Hospital'] 2
# ['Management Consulting'] 1
# ['Banking'] 1
# ['NGO', 'Social Services', 'Industry Associations'] 3
# ['Pharmaceutical & Life Sciences'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Education', 'Training'] 2
# ['Pharmaceutical & Life Sciences'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Chemicals'] 1
# ['Oil & Gas'] 1
# ['Management Consulting'] 1
# ['Financial Services'] 1
# ['Education', 'Training'] 2
# ['Management Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Education', 'Training'] 2
# ['Software Product'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['Automobile (Automobile Dealers)'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Hardware & Networking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Accounting', 'Auditing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['TV', 'Radio'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['IT Services & Consulting'] 1
# ['Textile & Apparel (Fashion)'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['Investment Banking', 'Venture Capital', 'Private Equity'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Real Estate'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['NBFC'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Electronic Components', 'Semiconductors'] 2
# ['Engineering & Construction'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Aviation'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Industrial Equipment', 'Machinery'] 2
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['Medical Devices & Equipment'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Miscellaneous'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['Miscellaneous'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['Courier', 'Logistics (Logistics Tech)'] 2
# ['Electronic Components', 'Semiconductors'] 2
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Investment Banking', 'Venture Capital', 'Private Equity'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['E-Learning', 'EdTech'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Automobile'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Internet'] 1
# ['Software Product'] 1
# ['E-Learning', 'EdTech'] 2
# ['E-Learning', 'EdTech'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Advertising & Marketing'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['E-Learning', 'EdTech'] 2
# ['E-Learning', 'EdTech'] 2
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Recruitment', 'Staffing'] 2
# ['Management Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Recruitment', 'Staffing'] 2
# ['Recruitment', 'Staffing'] 2
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Retail'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Medical Services', 'Hospital (Diagnostics)'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Automobile'] 1
# ['Retail'] 1
# ['Management Consulting'] 1
# ['Retail'] 1
# ['IT Services & Consulting'] 1
# ['Investment Banking', 'Venture Capital', 'Private Equity'] 3
# ['Financial Services (Broking)'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['Banking'] 1
# ['Banking'] 1
# ['Automobile (Electric Vehicle (EV))'] 1
# ['Software Product'] 1
# ['Travel & Tourism'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['TV', 'Radio'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Water Treatment', 'Waste Management'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['FMCG'] 1
# ['Financial Services'] 1
# ['Medical Services', 'Hospital'] 2
# ['Analytics', 'KPO', 'Research'] 3
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Education', 'Training'] 2
# ['Analytics', 'KPO', 'Research'] 3
# ['Education', 'Training'] 2
# ['Analytics', 'KPO', 'Research'] 3
# ['Biotechnology'] 1
# ['Biotechnology'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['Education', 'Training'] 2
# ['NGO', 'Social Services', 'Industry Associations'] 3
# ['Analytics', 'KPO', 'Research'] 3
# ['IT Services & Consulting'] 1
# ['Investment Banking', 'Venture Capital', 'Private Equity'] 3
# ['Management Consulting'] 1
# ['Education', 'Training'] 2
# ['Education', 'Training'] 2
# ['Management Consulting'] 1
# ['Oil & Gas'] 1
# ['Education', 'Training'] 2
# ['Management Consulting'] 1
# ['Management Consulting'] 1
# ['Management Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Pharmaceutical & Life Sciences'] 1
# ['Software Product'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Law Enforcement', 'Security Services'] 2
# ['Chemicals'] 1
# ['NGO', 'Social Services', 'Industry Associations'] 3
# ['Analytics', 'KPO', 'Research'] 3
# ['Analytics', 'KPO', 'Research'] 3
# ['Education', 'Training'] 2
# ['Analytics', 'KPO', 'Research'] 3
# ['Recruitment', 'Staffing'] 2
# ['Biotechnology'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Education', 'Training'] 2
# ['Analytics', 'KPO', 'Research'] 3
# ['Pharmaceutical & Life Sciences'] 1
# ['Management Consulting'] 1
# ['NGO', 'Social Services', 'Industry Associations'] 3
# ['Pharmaceutical & Life Sciences'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Pharmaceutical & Life Sciences'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Urban Transport'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Real Estate'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Hardware & Networking'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['Accounting', 'Auditing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Advertising & Marketing'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Real Estate'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['TV', 'Radio'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['TV', 'Radio'] 2
# ['Advertising & Marketing (Digital Marketing)'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Real Estate'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Real Estate'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Hardware & Networking'] 1
# ['IT Services & Consulting'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['TV', 'Radio'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Advertising & Marketing (Digital Marketing)'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Real Estate'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Printing & Publishing'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['TV', 'Radio'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Advertising & Marketing'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Real Estate'] 1
# ['Real Estate'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Automobile (Automobile Dealers)'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Automobile (Electric Vehicle (EV))'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Real Estate'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Hardware & Networking'] 1
# ['IT Services & Consulting'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['Printing & Publishing'] 1
# ['IT Services & Consulting'] 1
# ['Accounting', 'Auditing'] 2
# ['TV', 'Radio'] 2
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['Industrial Equipment', 'Machinery'] 2
# ['IT Services & Consulting'] 1
# ['Electronic Components', 'Semiconductors'] 2
# ['IT Services & Consulting'] 1
# ['Real Estate'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Electronic Components', 'Semiconductors'] 2
# ['Real Estate'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services (Broking)'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['FinTech', 'Payments'] 2
# ['Electronic Components', 'Semiconductors'] 2
# ['IT Services & Consulting'] 1
# ['Hotels & Restaurants'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['Travel & Tourism'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['NBFC (Micro Finance)'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['FinTech', 'Payments'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Software Product'] 1
# ['Retail'] 1
# ['Textile & Apparel'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['Gaming'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['Oil & Gas'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['Medical Services', 'Hospital'] 2
# ['Recruitment', 'Staffing'] 2
# ['Industrial Equipment', 'Machinery'] 2
# ['Emerging Technologies (IoT)'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['Medical Services', 'Hospital'] 2
# ['Internet'] 1
# ['Power (Solar)'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Telecom', 'ISP'] 2
# ['Banking'] 1
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['Advertising & Marketing (Digital Marketing)'] 1
# ['IT Services & Consulting'] 1
# ['Medical Services', 'Hospital'] 2
# ['Real Estate'] 1
# ['Electronics Manufacturing'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['FMCG'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Defence & Aerospace'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Metals & Mining'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Engineering & Construction'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Engineering & Construction'] 1
# ['IT Services & Consulting'] 1
# ['Animation & VFX'] 1
# ['IT Services & Consulting'] 1
# ['Emerging Technologies'] 1
# ['IT Services & Consulting'] 1
# ['Medical Devices & Equipment'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Retail'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Automobile'] 1
# ['IT Services & Consulting'] 1
# ['Events', 'Live Entertainment'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Software Product'] 1
# ['Financial Services'] 1
# ['Investment Banking', 'Venture Capital', 'Private Equity'] 3
# ['Electronic Components', 'Semiconductors'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Beverage'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Telecom', 'ISP'] 2
# ['Engineering & Construction'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Advertising & Marketing (Digital Marketing)'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Not mentioned'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Accounting', 'Auditing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Medical Devices & Equipment'] 1
# ['IT Services & Consulting'] 1
# ...
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Pharmaceutical & Life Sciences'] 1
# ['Software Product'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Insurance'] 1
# ['Industrial Automation'] 1
# ['Medical Devices & Equipment'] 1
# ['Film', 'Music', 'Entertainment'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Telecom', 'ISP'] 2
# ['Electronic Components', 'Semiconductors'] 2
# ['Consumer Electronics & Appliances'] 1
# ['IT Services & Consulting'] 1
# ['Industrial Automation'] 1
# ['Engineering & Construction'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Hardware & Networking'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Telecom', 'ISP'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Hardware & Networking'] 1
# ['BPM', 'BPO'] 2
# ['BPM', 'BPO'] 2
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Power'] 1
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Industrial Equipment', 'Machinery'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Industrial Equipment', 'Machinery'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Industrial Equipment', 'Machinery'] 2
# ['Industrial Equipment', 'Machinery'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['Real Estate (Co-working)'] 1
# ['Management Consulting'] 1
# ['Software Product'] 1
# ['BPM', 'BPO'] 2
# ['BPM', 'BPO'] 2
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Telecom', 'ISP'] 2
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['Industrial Equipment', 'Machinery'] 2
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['Water Treatment', 'Waste Management'] 2
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['Industrial Equipment', 'Machinery'] 2
# ['Recruitment', 'Staffing'] 2
# ['BPM', 'BPO'] 2
# ['BPM', 'BPO'] 2
# ['Advertising & Marketing (Digital Marketing)'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['Education', 'Training'] 2
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Insurance'] 1
# ['Banking'] 1
# ['E-Learning', 'EdTech'] 2
# ['Textile & Apparel'] 1
# ['FinTech', 'Payments'] 2
# ['Food Processing'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Engineering & Construction'] 1
# ['BPM', 'BPO'] 2
# ['BPM', 'BPO'] 2
# ['BPM', 'BPO'] 2
# ['Engineering & Construction'] 1
# ['Recruitment', 'Staffing'] 2
# ['Analytics', 'KPO', 'Research'] 3
# ['Petrochemical', 'Plastics', 'Rubber'] 3
# ['FMCG'] 1
# ['IT Services & Consulting'] 1
# ['Building Material'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Industrial Equipment', 'Machinery'] 2
# ['Analytics', 'KPO', 'Research'] 3
# ['Petrochemical', 'Plastics', 'Rubber'] 3
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Film', 'Music', 'Entertainment'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Retail'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet (E-Commerce)'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['Advertising & Marketing'] 1
# ['FinTech', 'Payments'] 2
# ['Advertising & Marketing'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Engineering & Construction'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Fitness & Wellness'] 1
# ['Gaming'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Import & Export'] 1
# ['Medical Services', 'Hospital'] 2
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['FinTech', 'Payments'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['FinTech', 'Payments'] 2
# ['Internet'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Advertising & Marketing'] 1
# ['FinTech', 'Payments'] 2
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Industrial Automation'] 1
# ['IT Services & Consulting'] 1
# ['FinTech', 'Payments'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Miscellaneous'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Industrial Automation'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['Education', 'Training'] 2
# ['Education', 'Training'] 2
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['Insurance'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['Education', 'Training'] 2
# ['Recruitment', 'Staffing'] 2
# ['Software Product'] 1
# ['Recruitment', 'Staffing'] 2
# ['Recruitment', 'Staffing'] 2
# ['Recruitment', 'Staffing'] 2
# ['Recruitment', 'Staffing'] 2
# ['FinTech', 'Payments'] 2
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['Industrial Equipment', 'Machinery'] 2
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Engineering & Construction'] 1
# ['Oil & Gas'] 1
# ['BPM', 'BPO'] 2
# ['Retail'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Engineering & Construction'] 1
# ['IT Services & Consulting'] 1
# ['Printing & Publishing'] 1
# ['Facility Management Services'] 1
# ['IT Services & Consulting'] 1
# ['Electronic Components', 'Semiconductors'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Defence & Aerospace'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Courier', 'Logistics'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Financial Services'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['BPM', 'BPO'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Biotechnology'] 1
# ['Biotechnology'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Banking'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Consumer Electronics & Appliances'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Emerging Technologies (IoT)'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Management Consulting'] 1
# ['Architecture', 'Interior Design'] 2
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['FinTech', 'Payments'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['Facility Management Services'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Analytics', 'KPO', 'Research'] 3
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Education', 'Training'] 2
# ['Analytics', 'KPO', 'Research'] 3
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Software Product'] 1
# ['IT Services & Consulting'] 1
# ['Internet'] 1
# ['Internet'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['Education', 'Training'] 2
# ['E-Learning', 'EdTech'] 2
# ['E-Learning', 'EdTech'] 2
# ['E-Learning', 'EdTech'] 2
# ['IT Services & Consulting'] 1
# ['E-Learning', 'EdTech'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Recruitment', 'Staffing'] 2
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Automobile'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['IT Services & Consulting'] 1
# ['Food Processing'] 1
# ['Management Consulting'] 1
# ['IT Services & Consulting'] 1

# %%
def clean_industry_type(value: str) -> list:
    """
    Clean the Industry Type value by splitting and removing unwanted characters.
    
    Args:
        value: The original Industry Type value.
    
    Returns:
        List of cleaned industry types.
    """
    if not isinstance(value, str):
        return value

    # 1. Replace the separator
    # 2. strip(" ,/") removes spaces, commas, AND slashes from the ends
    clean_industry = value.replace("/", ",").strip(" ,/")
    
    parts = clean_industry.split(",")
    
    # Optional: Clean up whitespace inside the list items too
    parts = [p.strip() for p in parts if p.strip()]
    
    return parts

df["Industry_Type_Cleaned"] = df["Industry Type"].apply(lambda x: clean_industry_type(x))
df["Industry_Type_Cleaned"].sample(10)
# Out:
# 12777                       [IT Services & Consulting]
# 7034                        [IT Services & Consulting]
# 14136                       [IT Services & Consulting]
# 6656                        [IT Services & Consulting]
# 7459                        [IT Services & Consulting]
# 8909                                       [Insurance]
# 13093           [Clinical Research, Contract Research]
# 4119                        [IT Services & Consulting]
# 11383    [NGO, Social Services, Industry Associations]
# 11215                       [IT Services & Consulting]
# Name: Industry_Type_Cleaned, dtype: object

# %% [markdown]
# #### Department Column Cleaning

# %%
df["Department"].sample(10)
# Out:
# 5285         Data Science & Analytics ,
# 3794         Data Science & Analytics ,
# 5037     Project & Program Management ,
# 9457         Data Science & Analytics ,
# 4368     Project & Program Management ,
# 2890     Project & Program Management ,
# 13663      Healthcare & Life Sciences ,
# 7609      Engineering - Software & QA ,
# 10042      UX , Design & Architecture ,
# 4251      Engineering - Software & QA ,
# Name: Department, dtype: object

# %%
def clean_department(value: str) -> list:
    """
    Clean the Department value by splitting and removing unwanted characters.
    
    Args:
        value: The original Department value.

    Returns:
        List of cleaned department names.
    """
    if not isinstance(value, str):
        return value

    # 1. Replace the separator
    # 2. strip(" ,/") removes spaces, commas, AND slashes from the ends
    clean_department = value.replace("/", ",").strip(" ,/&")
    
    parts = clean_department.split("-")
    
    # Optional: Clean up whitespace inside the list items too
    parts = [p.strip() for p in parts if p.strip()]
    
    return parts

df["Department_Cleaned"] = df["Department"].apply(lambda x: clean_department(x))
df["Department_Cleaned"].sample(10)
# Out:
# 1659           [UX , Design & Architecture]
# 10629            [Data Science & Analytics]
# 9512           [Engineering, Software & QA]
# 13378              [Research & Development]
# 6272     [Engineering, Hardware & Networks]
# 11525          [Engineering, Software & QA]
# 1123           [Engineering, Software & QA]
# 7506                                [Other]
# 12837          [Engineering, Software & QA]
# 10171          [Engineering, Software & QA]
# Name: Department_Cleaned, dtype: object

# %%
# updated code:
import re
import pandas as pd
from typing import List, Union

# Department normalization mapping
DEPARTMENT_NORMALIZATION = {
    # IT & Technology
    'it': 'Information Technology',
    'information technology': 'Information Technology',
    'tech': 'Technology',
    'technology': 'Technology',
    'software': 'Software Development',
    'software development': 'Software Development',
    'software engineering': 'Software Engineering',
    'engineering': 'Engineering',
    'data': 'Data Science',
    'data science': 'Data Science',
    'analytics': 'Analytics',
    'ai': 'Artificial Intelligence',
    'ml': 'Machine Learning',
    
    # Business Functions
    'hr': 'Human Resources',
    'human resources': 'Human Resources',
    'human resource': 'Human Resources',
    'finance': 'Finance',
    'accounts': 'Finance',
    'accounting': 'Finance',
    'sales': 'Sales',
    'marketing': 'Marketing',
    'sales & marketing': 'Sales & Marketing',
    'sales and marketing': 'Sales & Marketing',
    'operations': 'Operations',
    'ops': 'Operations',
    'admin': 'Administration',
    'administration': 'Administration',
    'legal': 'Legal',
    
    # R&D and Product
    'r&d': 'Research & Development',
    'research': 'Research & Development',
    'research and development': 'Research & Development',
    'product': 'Product Management',
    'product management': 'Product Management',
    'project management': 'Project Management',
    'pmo': 'Project Management Office',
    
    # Operations & Support
    'customer service': 'Customer Service',
    'customer support': 'Customer Support',
    'support': 'Customer Support',
    'technical support': 'Technical Support',
    'quality': 'Quality Assurance',
    'qa': 'Quality Assurance',
    'quality assurance': 'Quality Assurance',
    'testing': 'Quality Assurance',
    
    # Design & Creative
    'design': 'Design',
    'ui/ux': 'UI/UX Design',
    'ux': 'UX Design',
    'ui': 'UI Design',
    'creative': 'Creative',
    'graphics': 'Graphics Design',
    
    # Infrastructure
    'devops': 'DevOps',
    'infrastructure': 'Infrastructure',
    'network': 'Network',
    'security': 'Security',
    'cybersecurity': 'Cybersecurity',
    'cloud': 'Cloud',
    
    # Manufacturing & Production
    'production': 'Production',
    'manufacturing': 'Manufacturing',
    'supply chain': 'Supply Chain',
    'logistics': 'Logistics',
    'procurement': 'Procurement',
    
    # Consulting & Advisory
    'consulting': 'Consulting',
    'advisory': 'Advisory',
    'strategy': 'Strategy',
    
    # Other
    'general': 'General',
    'other': 'Other',
    'misc': 'Miscellaneous',
    'miscellaneous': 'Miscellaneous',
}

# Invalid department names to exclude
INVALID_DEPARTMENTS = {
    'na', 'n/a', 'none', 'not specified', 'not mentioned',
    'any', 'all', 'multiple', 'various', 'tbd', 'to be decided'
}


def normalize_department(dept: str) -> Union[str, None]:
    """
    Normalize a single department name.
    
    Args:
        dept: Raw department string
        
    Returns:
        Normalized department name or None if invalid
    """
    if not dept or not isinstance(dept, str):
        return None
    
    # Clean and normalize
    dept = dept.strip().lower()
    
    # Remove common punctuation at edges
    dept = re.sub(r'^[.,;:\-/|()&]+|[.,;:\-/|()&]+$', '', dept).strip()
    
    # Skip if empty or too short
    if not dept or len(dept) < 2:
        return None
    
    # Skip if in invalid list
    if dept in INVALID_DEPARTMENTS:
        return None
    
    # Normalize using mapping
    if dept in DEPARTMENT_NORMALIZATION:
        return DEPARTMENT_NORMALIZATION[dept]
    
    # Return title-cased version if not in mapping
    return dept.title()


def clean_department(value: Union[str, List]) -> List[str]:
    """
    Clean department value by splitting, normalizing, and deduplicating.
    
    Args:
        value: Department string or list
        
    Returns:
        List of unique, normalized department names
        
    Examples:
        "IT/HR/Sales" → ["Information Technology", "Human Resources", "Sales"]
        "Engineering, R&D" → ["Engineering", "Research & Development"]
        "IT, IT, Information Technology" → ["Information Technology"]
    """
    # Handle None, NaN, or empty
    if pd.isna(value) or not value:
        return []
    
    # If already a list
    if isinstance(value, list):
        dept_list = [str(d).strip() for d in value if d]
    else:
        # Convert to string
        value = str(value).strip()
        
        # Remove surrounding brackets if present
        value = re.sub(r'^\[|\]$', '', value)
        
        # Remove quotes
        value = re.sub(r'["\']', '', value)
        
        # Split on multiple separators: comma, slash, hyphen, pipe, ampersand
        # Use regex to split on any of these characters
        dept_list = re.split(r'[,/\-|&]', value)
        
        # Clean each department
        dept_list = [d.strip() for d in dept_list if d and d.strip()]
    
    # Normalize all departments
    normalized = [normalize_department(d) for d in dept_list]
    
    # Remove None values and deduplicate while preserving order
    seen = {}
    for dept in normalized:
        if dept is not None:
            seen[dept] = None
    
    return list(seen.keys())


def get_primary_department(dept_list: List[str]) -> Union[str, None]:
    """Get the first (primary) department from list."""
    return dept_list[0] if dept_list else None


def has_department(dept_list: List[str], target_dept: str) -> bool:
    """Check if target department is in list (case-insensitive)."""
    if not isinstance(dept_list, list):
        return False
    target_normalized = normalize_department(target_dept)
    return target_normalized in dept_list if target_normalized else False


def get_department_count(dept_list: List[str]) -> int:
    """Get count of departments."""
    return len(dept_list) if isinstance(dept_list, list) else 0


# Test cases
test_cases = [
    "IT/HR/Sales",
    "Engineering, R&D",
    "IT, IT, Information Technology",
    "Software Development - Quality Assurance",
    "Sales & Marketing",
    "Finance/Accounts/Admin",
    "DevOps | Cloud | Infrastructure",
    "Product Management, Engineering",
    "NA",
    "Not Specified",
    "",
    None,
    "IT",
    "Human Resources",
    "R&D, Product, Engineering",
    "Data Science/Analytics/AI/ML",
    "[Marketing, Sales]",
    "'IT', 'HR', 'Finance'",
]

print("Testing Department Cleaning:")
print("-" * 100)
for test in test_cases:
    result = clean_department(test)
    primary = get_primary_department(result)
    count = get_department_count(result)
    print(f"Input:   {repr(test):<50}")
    print(f"Output:  {result}")
    print(f"Primary: {primary} | Count: {count}")
    print()

print("=" * 100)
print("Example DataFrame Usage:")
print("=" * 100)

# Example with DataFrame
sample_data = {
    'Department': [
        "IT/HR/Sales",
        "Engineering, R&D",
        "IT, IT, Information Technology",
        "Sales & Marketing",
        "NA",
        "Product Management, Engineering",
        None
    ]
}

df_example = pd.DataFrame(sample_data)

# Apply cleaning
df_example['Department_Cleaned'] = df_example['Department'].apply(clean_department)
df_example['Primary_Department'] = df_example['Department_Cleaned'].apply(get_primary_department)
df_example['Department_Count'] = df_example['Department_Cleaned'].apply(get_department_count)

# Check for specific departments
df_example['Has_IT'] = df_example['Department_Cleaned'].apply(lambda x: has_department(x, 'IT'))
df_example['Has_Engineering'] = df_example['Department_Cleaned'].apply(lambda x: has_department(x, 'Engineering'))

print(df_example[['Department', 'Department_Cleaned', 'Primary_Department', 'Department_Count']])

print("\n" + "=" * 100)
print("Recommended Usage:")
print("=" * 100)
print("""
# Apply department cleaning
df['Department_Cleaned'] = df['Department'].apply(clean_department)
df['Primary_Department'] = df['Department_Cleaned'].apply(get_primary_department)
df['Department_Count'] = df['Department_Cleaned'].apply(get_department_count)

# Filter by department
it_jobs = df[df['Department_Cleaned'].apply(lambda x: has_department(x, 'IT'))]
engineering_jobs = df[df['Primary_Department'] == 'Engineering']

# Department frequency analysis
from collections import Counter
all_depts = [dept for depts in df['Department_Cleaned'] for dept in depts]
dept_frequency = Counter(all_depts)
print(dept_frequency.most_common(20))

# Multi-department jobs
multi_dept_jobs = df[df['Department_Count'] > 1]

# Cross-functional roles (e.g., IT + Sales)
it_sales_jobs = df[df['Department_Cleaned'].apply(
    lambda x: has_department(x, 'IT') and has_department(x, 'Sales')
)]
""")
# Out:
# Testing Department Cleaning:
# ----------------------------------------------------------------------------------------------------
# Input:   'IT/HR/Sales'
# Output:  ['Information Technology', 'Human Resources', 'Sales']
# Primary: Information Technology | Count: 3
#
# Input:   'Engineering, R&D'
# Output:  ['Engineering']
# Primary: Engineering | Count: 1
#
# Input:   'IT, IT, Information Technology'
# Output:  ['Information Technology']
# Primary: Information Technology | Count: 1
#
# Input:   'Software Development - Quality Assurance'
# Output:  ['Software Development', 'Quality Assurance']
# Primary: Software Development | Count: 2
#
# Input:   'Sales & Marketing'
# Output:  ['Sales', 'Marketing']
# Primary: Sales | Count: 2
#
# Input:   'Finance/Accounts/Admin'
# Output:  ['Finance', 'Administration']
# Primary: Finance | Count: 2
#
# Input:   'DevOps | Cloud | Infrastructure'
# Output:  ['DevOps', 'Cloud', 'Infrastructure']
# Primary: DevOps | Count: 3
#
# Input:   'Product Management, Engineering'
# Output:  ['Product Management', 'Engineering']
# Primary: Product Management | Count: 2
#
# Input:   'NA'
# Output:  []
# Primary: None | Count: 0
#
# Input:   'Not Specified'
# Output:  []
# Primary: None | Count: 0
#
# Input:   ''
# Output:  []
# Primary: None | Count: 0
#
# Input:   None
# Output:  []
# Primary: None | Count: 0
#
# Input:   'IT'
# Output:  ['Information Technology']
# Primary: Information Technology | Count: 1
#
# Input:   'Human Resources'
# Output:  ['Human Resources']
# Primary: Human Resources | Count: 1
#
# Input:   'R&D, Product, Engineering'
# Output:  ['Product Management', 'Engineering']
# Primary: Product Management | Count: 2
#
# Input:   'Data Science/Analytics/AI/ML'
# Output:  ['Data Science', 'Analytics', 'Artificial Intelligence', 'Machine Learning']
# Primary: Data Science | Count: 4
#
# Input:   '[Marketing, Sales]'
# Output:  ['Marketing', 'Sales']
# Primary: Marketing | Count: 2
#
# Input:   "'IT', 'HR', 'Finance'"
# Output:  ['Information Technology', 'Human Resources', 'Finance']
# Primary: Information Technology | Count: 3
#
# ====================================================================================================
# Example DataFrame Usage:
# ====================================================================================================
#                         Department  \
# 0                      IT/HR/Sales
# 1                 Engineering, R&D
# 2   IT, IT, Information Technology
# 3                Sales & Marketing
# 4                               NA
# 5  Product Management, Engineering
# 6                             None
#
#                                  Department_Cleaned      Primary_Department  \
# 0  [Information Technology, Human Resources, Sales]  Information Technology
# 1                                     [Engineering]             Engineering
# 2                          [Information Technology]  Information Technology
# 3                                [Sales, Marketing]                   Sales
# 4                                                []                    None
# 5                 [Product Management, Engineering]      Product Management
# 6                                                []                    None
#
#    Department_Count
# 0                 3
# 1                 1
# 2                 1
# 3                 2
# 4                 0
# 5                 2
# 6                 0
#
# ====================================================================================================
# Recommended Usage:
# ====================================================================================================
#
# # Apply department cleaning
# df['Department_Cleaned'] = df['Department'].apply(clean_department)
# df['Primary_Department'] = df['Department_Cleaned'].apply(get_primary_department)
# df['Department_Count'] = df['Department_Cleaned'].apply(get_department_count)
#
# # Filter by department
# it_jobs = df[df['Department_Cleaned'].apply(lambda x: has_department(x, 'IT'))]
# engineering_jobs = df[df['Primary_Department'] == 'Engineering']
#
# # Department frequency analysis
# from collections import Counter
# all_depts = [dept for depts in df['Department_Cleaned'] for dept in depts]
# dept_frequency = Counter(all_depts)
# print(dept_frequency.most_common(20))
#
# # Multi-department jobs
# multi_dept_jobs = df[df['Department_Count'] > 1]
#
# # Cross-functional roles (e.g., IT + Sales)
# it_sales_jobs = df[df['Department_Cleaned'].apply(
# 2025-12-11
# 2025-12-12
# 2025-12-13
# 2025-12-14
# 2025-12-15
# 2025-12-16
# 2025-12-17
# 2025-12-18
# 2025-12-19
# 2025-12-20
# 2025-12-28
# 2025-12-29

# %%
df["Scraped_At"].str.split("T").str[0].unique()
# Out:
# array(['2025-12-03', '2025-12-07', '2025-12-09', '2025-12-10',
#        '2025-12-11', '2025-12-12', '2025-12-13', '2025-12-14',
#        '2025-12-15', '2025-12-16', '2025-12-17', '2025-12-18',
#        '2025-12-19', '2025-12-20', '2025-12-28', '2025-12-29'],
#       dtype=object)

# %% [markdown]
# #### Cleaning Timestamp

# %%
def clean_timestamp(value: str) -> str:
    """
    Clean the timestamp value by extracting the date part.
    
    Args:
        value: The original timestamp value.
    
    Returns:
        Cleaned date string in 'YYYY-MM-DD' format.
    """
    if not isinstance(value, str):
        return value

    # Split by "T" and take the first part
    date_part = value.split("T")[0]
    
    return date_part

df["Scraped_At_Cleaned"] = df["Scraped_At"].apply(lambda x: clean_timestamp(x))
df["Scraped_At_Cleaned"].sample(10)
# Out:
# 4505     2025-12-13
# 11123    2025-12-19
# 6499     2025-12-14
# 1257     2025-12-11
# 10139    2025-12-17
# 5157     2025-12-13
# 1152     2025-12-11
# 2352     2025-12-12
# 2016     2025-12-12
# 8431     2025-12-16
# Name: Scraped_At_Cleaned, dtype: object

# %% [markdown]
# #### Description Column Cleaning

# %%
df["Description"].sample(10)
# Out:
# 7035     Position: Senior AI/ML & Gen AI Engineer Exper...
# 1238     About The Role Project Role : Data Engineer Pr...
# 11151    Design, develop, and deploy state-of-the-art M...
# 9917     Role & responsibilities Drive the product- and...
# 5160     We are looking for a Ruby on Rails developer r...
# 7081     Adroit Market Research is looking for Research...
# 8186     Candidates with minimum 2 years (mandatory) of...
# 10933    About The Role Project Role : DevOps Engineer ...
# 3565     Role Description: The SAP Scrum Master is a le...
# 12153    Media3 International Pvt Ltd.  is looking for ...
# Name: Description, dtype: object

# %%
def clean_description(value: str) -> str:
    """
    Clean the job description by removing unwanted characters.
    
    Args:
        value: The original job description.
    
    Returns:
        Cleaned job description string.
    """
    if not isinstance(value, str):
        return value

    # Example cleaning: Remove excessive whitespace
    cleaned_description = ' '.join(value.split())
    
    return cleaned_description

df["Description_Cleaned"] = df["Description"].apply(lambda x: clean_description(x))
df["Description_Cleaned"].sample(10)
# Out:
# 545      About The Role Role Purpose The purpose of thi...
# 7884     Job Title: Back End Developer Location: Bavdha...
# 9209     Job Description : Job Description: We are look...
# 3565     Role Description: The SAP Scrum Master is a le...
# 13483    About The Role Project Role : Custom Software ...
# 5954     Skill : Program Management and Coordination Ro...
# 8766     We are seeking a creative and detail-oriented ...
# 10258    Daily Incident Review Reviews all the incident...
# 10174    Role: DevOps Engineer Duration: Contract Locat...
# 2846     As a Product Manager in Asset and Wealth Manag...
# Name: Description_Cleaned, dtype: object

# %%
# storing clean df
df.to_csv(r"D:\DATA SCIENCE AND ML\Project\job_trend_predictor\data\processed\cleaned\cleaned_job_data.csv", index=False)
