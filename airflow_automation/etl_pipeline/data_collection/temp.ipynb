# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# d:\DATA SCIENCE AND ML\job_trend_predictor\airflow_automation\etl_pipeline\data_collection

# %%
df = pd.read_csv(r"D:\DATA SCIENCE AND ML\job_trend_predictor\airflow_automation\etl_pipeline\data\raw\scraped_data.csv")
df.head()
# Out:
#          Job Type                                     Title  \
# 0  Data Scientist                            Data Scientist
# 1  Data Scientist                            Data Scientist
# 2  Data Scientist                            Data Scientist
# 3  Data Scientist                            Data Scientist
# 4  Data Scientist  Data Scientist - Artificial Intelligence
#
#                 Company    Experience         Salary   Location  \
# 0             Blue Star   0 - 2 years  Not Disclosed      Thane
# 1             Capgemini   4 - 7 years  Not Disclosed  Bengaluru
# 2             Cognizant  8 - 10 years  Not Disclosed    Chennai
# 3  Kotak Life Insurance  5 - 10 years  Not Disclosed  Bengaluru
# 4                   IBM   3 - 6 years  Not Disclosed  Bengaluru
#
#                                            Education  \
# 0        EducationUG:Any GraduatePG:Any Postgraduate
# 1        EducationUG:Any GraduatePG:Any Postgraduate
# 2              EducationPG:LLM in Any Specialization
# 3        EducationUG:Any GraduatePG:Any Postgraduate
# 4  EducationUG:B.Tech/B.E. in Any SpecializationP...
#
#                                               Skills  \
# 0  [[], ['algorithms', 'python', 'modeling', 'dat...
# 1  [['python', 'machine learning', 'tensorflow', ...
# 2  [[], ['kubernetes', 'algorithms', 'python', 'd...
# 3  [['software development', 'presentation skills...
# 4  [['Artificial Intelligence'], ['Data Science',...
#
#                           Role                       Industry Type  \
# 0             Data Scientist ,  Industrial Equipment / Machinery ,
# 1             Data Scientist ,          IT Services & Consulting ,
# 2  Full Stack Data Scientist ,          IT Services & Consulting ,
# 3  Full Stack Data Scientist ,          IT Services & Consulting ,
# 4             Data Scientist ,          IT Services & Consulting ,
#
#                    Department       Employment Type  \
# 0  Data Science & Analytics ,  Full Time, Permanent
# 1  Data Science & Analytics ,  Full Time, Permanent
# 2  Data Science & Analytics ,  Full Time, Permanent
# 3  Data Science & Analytics ,  Full Time, Permanent
# 4  Data Science & Analytics ,  Full Time, Permanent
#
#                      Role Category  \
# 0  Data Science & Machine Learning
# 1  Data Science & Machine Learning
# 2  Data Science & Machine Learning
# 3  Data Science & Machine Learning
# 4  Data Science & Machine Learning
#
#                                          Description  \
# 0  Blue Star Ltd is looking for Data Scientist to...
# 1  Your Role Gen AI ,Computer vision, Cloud exp ,...
# 2  Role –Gen AI Engineer (Senior / Manager) Job L...
# 3  About The Role What we offer Our mission is si...
# 4  As an Associate Data Scientist at IBM, you wil...
#
#                                              Job URL            Timestamp
# 0  https://www.naukri.com/job-listings-data-scien...  2025-09-17 05:44:17
# 1  https://www.naukri.com/job-listings-data-scien...  2025-09-17 05:44:22
# 2  https://www.naukri.com/job-listings-data-scien...  2025-09-17 05:44:28
# 3  https://www.naukri.com/job-listings-data-scien...  2025-09-17 05:44:35
# 4  https://www.naukri.com/job-listings-data-scien...  2025-09-17 05:44:41
